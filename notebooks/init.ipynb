# %% [markdown]
# # Notebook Init
#
# Run this notebook once per kernel before working with the demo notebooks.

# %%
import os
import subprocess
import sys
from pathlib import Path

repo_root = next(
    root for root in [Path.cwd(), *Path.cwd().parents]
    if (root / "conditional_node_field_graph_generator").exists()
)
nsppk_candidates = [
    repo_root.parent / "NSPPK",
    repo_root.parent / "nsppk",
]
local_nsppk_repo = next(
    (
        candidate.resolve()
        for candidate in nsppk_candidates
        if (candidate / "pyproject.toml").exists() or (candidate / "setup.py").exists()
    ),
    None,
)
if local_nsppk_repo is not None:
    print(f"Installing local NSPPK checkout from {local_nsppk_repo}")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(local_nsppk_repo)])
elif os.environ.get("NODEFIELD_SKIP_NSPPK") != "1":
    raise RuntimeError(
        "Could not find a local NSPPK checkout. Expected one of: "
        + ", ".join(str(path) for path in nsppk_candidates)
        + ". Set NODEFIELD_SKIP_NSPPK=1 only if the current notebook does not require NSPPK."
    )

ecosystem_root = repo_root.parent / "abstractgraph-ecosystem" / "repos"
ecosystem_packages = [
    ecosystem_root / "abstractgraph",
    ecosystem_root / "abstractgraph-ml",
    ecosystem_root / "abstractgraph-graphicalizer",
]
missing_ecosystem_packages = [path for path in ecosystem_packages if not (path / "pyproject.toml").exists()]
if missing_ecosystem_packages:
    raise RuntimeError(
        "Could not find local AbstractGraph ecosystem checkouts: "
        + ", ".join(str(path) for path in missing_ecosystem_packages)
    )

print(f"Installing local AbstractGraph ecosystem from {ecosystem_root}")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(ecosystem_packages[0])])
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(ecosystem_packages[1])])
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", ".[chem]"], cwd=ecosystem_packages[2])

print(f"Installing NodeField notebook dependencies from {repo_root}")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", "."], cwd=repo_root)
# Out:
# Installing local NSPPK checkout from /home/fabrizio/code/NSPPK
# Obtaining file:///home/fabrizio/code/NSPPK
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx>=3.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nsppk==0.1.0) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nsppk==0.1.0) (2.4.3)
# Requirement already satisfied: scipy>=1.10 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nsppk==0.1.0) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nsppk==0.1.0) (1.8.0)
# Requirement already satisfied: matplotlib>=3.7 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nsppk==0.1.0) (3.10.8)
# Requirement already satisfied: multiprocessing-on-dill>=3.5.0a4 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nsppk==0.1.0) (3.5.0a4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (26.0)
# Requirement already satisfied: pillow>=8 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (2.9.0.post0)
# Requirement already satisfied: dill in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from multiprocessing-on-dill>=3.5.0a4->nsppk==0.1.0) (0.4.1)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->nsppk==0.1.0) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from scikit-learn>=1.3->nsppk==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from scikit-learn>=1.3->nsppk==0.1.0) (3.6.0)
# Building wheels for collected packages: nsppk
#   Building editable for nsppk (pyproject.toml): started
#   Building editable for nsppk (pyproject.toml): finished with status 'done'
#   Created wheel for nsppk: filename=nsppk-0.1.0-0.editable-py3-none-any.whl size=6801 sha256=577c6d42623955a717f32128cc499bab653c1868e5914e30d1e3e9e5be961af7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-y0s6_coa/wheels/b3/f4/98/5a7497885bfcb8cb048a717f611b78b8e914cbe6baea372590
# Successfully built nsppk
# Installing collected packages: nsppk
#   Attempting uninstall: nsppk
#     Found existing installation: nsppk 0.1.0
#     Uninstalling nsppk-0.1.0:
#       Successfully uninstalled nsppk-0.1.0
# Successfully installed nsppk-0.1.0
# Installing local AbstractGraph ecosystem from /home/fabrizio/code/abstractgraph-ecosystem/repos
# Obtaining file:///home/fabrizio/code/abstractgraph-ecosystem/repos/abstractgraph
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx>=3.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph==0.1.0) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph==0.1.0) (2.4.3)
# Requirement already satisfied: scipy>=1.10 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph==0.1.0) (1.17.1)
# Requirement already satisfied: joblib>=1.3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph==0.1.0) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph==0.1.0) (1.8.0)
# Requirement already satisfied: matplotlib>=3.7 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph==0.1.0) (3.10.8)
# Requirement already satisfied: toolz>=0.12 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph==0.1.0) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (26.0)
# Requirement already satisfied: pillow>=8 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->abstractgraph==0.1.0) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from scikit-learn>=1.3->abstractgraph==0.1.0) (3.6.0)
# Building wheels for collected packages: abstractgraph
#   Building editable for abstractgraph (pyproject.toml): started
#   Building editable for abstractgraph (pyproject.toml): finished with status 'done'
#   Created wheel for abstractgraph: filename=abstractgraph-0.1.0-0.editable-py3-none-any.whl size=2862 sha256=da4f2b263dd3a57a646d9d5b91c95623b8ced27de04e798867997c4af1e72bda
#   Stored in directory: /tmp/pip-ephem-wheel-cache-icyccggc/wheels/aa/d5/30/2dbdaaec05110f6d04f0041b82df4ec281120946d126cfdf90
# Successfully built abstractgraph
# Installing collected packages: abstractgraph
#   Attempting uninstall: abstractgraph
#     Found existing installation: abstractgraph 0.1.0
#     Uninstalling abstractgraph-0.1.0:
#       Successfully uninstalled abstractgraph-0.1.0
# Successfully installed abstractgraph-0.1.0
# Obtaining file:///home/fabrizio/code/abstractgraph-ecosystem/repos/abstractgraph-ml
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: abstractgraph>=0.1.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-ml==0.1.0) (0.1.0)
# Requirement already satisfied: matplotlib>=3.8 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-ml==0.1.0) (3.10.8)
# Requirement already satisfied: numpy>=1.24 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-ml==0.1.0) (2.4.3)
# Requirement already satisfied: pandas>=2.2 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-ml==0.1.0) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-ml==0.1.0) (1.8.0)
# Requirement already satisfied: networkx>=3.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (3.6.1)
# Requirement already satisfied: scipy>=1.10 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (1.17.1)
# Requirement already satisfied: joblib>=1.3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (1.5.3)
# Requirement already satisfied: toolz>=0.12 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (26.0)
# Requirement already satisfied: pillow>=8 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.8->abstractgraph-ml==0.1.0) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from scikit-learn>=1.3->abstractgraph-ml==0.1.0) (3.6.0)
# Building wheels for collected packages: abstractgraph-ml
#   Building editable for abstractgraph-ml (pyproject.toml): started
#   Building editable for abstractgraph-ml (pyproject.toml): finished with status 'done'
#   Created wheel for abstractgraph-ml: filename=abstractgraph_ml-0.1.0-0.editable-py3-none-any.whl size=3311 sha256=789d532b1c15bbd1dad7f8f234f3dbfc63ddec920372845cfb7015db89f651a9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-qi6q7otp/wheels/e0/a7/1b/9e3d34c98cd8dc229fc02709b39968581ed7add65a56c90803
# Successfully built abstractgraph-ml
# Installing collected packages: abstractgraph-ml
#   Attempting uninstall: abstractgraph-ml
#     Found existing installation: abstractgraph-ml 0.1.0
#     Uninstalling abstractgraph-ml-0.1.0:
#       Successfully uninstalled abstractgraph-ml-0.1.0
# Successfully installed abstractgraph-ml-0.1.0
# Obtaining file:///home/fabrizio/code/abstractgraph-ecosystem/repos/abstractgraph-graphicalizer
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx>=3.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-graphicalizer==0.1.0) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-graphicalizer==0.1.0) (2.4.3)
# Requirement already satisfied: scipy>=1.11 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-graphicalizer==0.1.0) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-graphicalizer==0.1.0) (1.8.0)
# Requirement already satisfied: matplotlib>=3.7 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-graphicalizer==0.1.0) (3.10.8)
# Requirement already satisfied: Pillow>=10.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-graphicalizer==0.1.0) (12.1.1)
# Requirement already satisfied: torch>=2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-graphicalizer==0.1.0) (2.10.0+cpu)
# Requirement already satisfied: rdkit>=2023.9.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from abstractgraph-graphicalizer==0.1.0) (2025.9.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (26.0)
# Requirement already satisfied: pyparsing>=3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from scikit-learn>=1.3->abstractgraph-graphicalizer==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from scikit-learn>=1.3->abstractgraph-graphicalizer==0.1.0) (3.6.0)
# Requirement already satisfied: filelock in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (4.15.0)
# Requirement already satisfied: setuptools in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (1.14.0)
# Requirement already satisfied: jinja2 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (2026.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from jinja2->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.0.3)
# Building wheels for collected packages: abstractgraph-graphicalizer
#   Building editable for abstractgraph-graphicalizer (pyproject.toml): started
#   Building editable for abstractgraph-graphicalizer (pyproject.toml): finished with status 'done'
#   Created wheel for abstractgraph-graphicalizer: filename=abstractgraph_graphicalizer-0.1.0-0.editable-py3-none-any.whl size=3759 sha256=20d391bcc8b1795cab5816fdded17ec81bf5d043067d3e2bfc084d3dc24efa10
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u99forul/wheels/4e/96/82/34db73269ddd35f497f9f7f2ee9d003dd11166b00c1c14ccef
# Successfully built abstractgraph-graphicalizer
# Installing collected packages: abstractgraph-graphicalizer
#   Attempting uninstall: abstractgraph-graphicalizer
#     Found existing installation: abstractgraph-graphicalizer 0.1.0
#     Uninstalling abstractgraph-graphicalizer-0.1.0:
#       Successfully uninstalled abstractgraph-graphicalizer-0.1.0
# Successfully installed abstractgraph-graphicalizer-0.1.0
# Installing NodeField notebook dependencies from /home/fabrizio/code/NodeField
# Obtaining file:///home/fabrizio/code/NodeField
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy<3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (2.4.3)
# Requirement already satisfied: torch in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (2.10.0+cpu)
# Requirement already satisfied: pytorch-lightning in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (2.6.1)
# Requirement already satisfied: scipy in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (1.17.1)
# Requirement already satisfied: pandas in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (3.0.1)
# Requirement already satisfied: scikit-learn in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (1.8.0)
# Requirement already satisfied: networkx in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (3.6.1)
# Requirement already satisfied: matplotlib in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (3.10.8)
# Requirement already satisfied: pulp in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (3.3.0)
# Requirement already satisfied: dill in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (0.4.1)
# Requirement already satisfied: requests in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (2.32.5)
# Requirement already satisfied: toolz in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from nodefield==0.0.1) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib->nodefield==0.0.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib->nodefield==0.0.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib->nodefield==0.0.1) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib->nodefield==0.0.1) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib->nodefield==0.0.1) (26.0)
# Requirement already satisfied: pillow>=8 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib->nodefield==0.0.1) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib->nodefield==0.0.1) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from matplotlib->nodefield==0.0.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->nodefield==0.0.1) (1.17.0)
# Requirement already satisfied: tqdm>=4.57.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from pytorch-lightning->nodefield==0.0.1) (4.67.3)
# Requirement already satisfied: PyYAML>5.4 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from pytorch-lightning->nodefield==0.0.1) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (2026.2.0)
# Requirement already satisfied: torchmetrics>0.7.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from pytorch-lightning->nodefield==0.0.1) (1.9.0)
# Requirement already satisfied: typing-extensions>4.5.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from pytorch-lightning->nodefield==0.0.1) (4.15.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from pytorch-lightning->nodefield==0.0.1) (0.15.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (3.13.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->nodefield==0.0.1) (3.11)
# Requirement already satisfied: filelock in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch->nodefield==0.0.1) (3.25.2)
# Requirement already satisfied: setuptools in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch->nodefield==0.0.1) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch->nodefield==0.0.1) (1.14.0)
# Requirement already satisfied: jinja2 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from torch->nodefield==0.0.1) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from sympy>=1.13.3->torch->nodefield==0.0.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from jinja2->torch->nodefield==0.0.1) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from requests->nodefield==0.0.1) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from requests->nodefield==0.0.1) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from requests->nodefield==0.0.1) (2026.2.25)
# Requirement already satisfied: joblib>=1.3.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from scikit-learn->nodefield==0.0.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py313/lib/python3.13/site-packages (from scikit-learn->nodefield==0.0.1) (3.6.0)
# Building wheels for collected packages: nodefield
#   Building editable for nodefield (pyproject.toml): started
#   Building editable for nodefield (pyproject.toml): finished with status 'done'
#   Created wheel for nodefield: filename=nodefield-0.0.1-0.editable-py3-none-any.whl size=7643 sha256=8b2bdedbd284fd30b0f01ab657a43598aa550f8369641fd5d6575a95cc00d574
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xiz3nash/wheels/df/5c/af/a45aaefb4e1f60d68a0505e81d2eab0aa8dc785cb827fb81c7
# Successfully built nodefield
# Installing collected packages: nodefield
#   Attempting uninstall: nodefield
#     Found existing installation: nodefield 0.0.1
#     Not uninstalling nodefield at /home/fabrizio/code/NodeField, outside environment /home/fabrizio/.venvs/py313
#     Can't uninstall 'nodefield'. No files were found to uninstall.
# Successfully installed nodefield-0.0.1
# 0
