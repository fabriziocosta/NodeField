# %% [markdown]
# # Notebook Init
#
# Run this notebook once per kernel before working with the demo notebooks.

# %%
import os
import subprocess
import sys
from pathlib import Path

repo_root = next(
    root for root in [Path.cwd(), *Path.cwd().parents]
    if (root / "conditional_node_field_graph_generator").exists()
)
nsppk_candidates = [
    repo_root.parent / "NSPPK",
    repo_root.parent / "nsppk",
]
local_nsppk_repo = next(
    (
        candidate.resolve()
        for candidate in nsppk_candidates
        if (candidate / "pyproject.toml").exists() or (candidate / "setup.py").exists()
    ),
    None,
)
if local_nsppk_repo is not None:
    print(f"Installing local NSPPK checkout from {local_nsppk_repo}")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(local_nsppk_repo)])
elif os.environ.get("NODEFIELD_SKIP_NSPPK") != "1":
    raise RuntimeError(
        "Could not find a local NSPPK checkout. Expected one of: "
        + ", ".join(str(path) for path in nsppk_candidates)
        + ". Set NODEFIELD_SKIP_NSPPK=1 only if the current notebook does not require NSPPK."
    )

ecosystem_root = repo_root.parent / "abstractgraph-ecosystem" / "repos"
ecosystem_packages = [
    ecosystem_root / "abstractgraph",
    ecosystem_root / "abstractgraph-ml",
    ecosystem_root / "abstractgraph-graphicalizer",
]
missing_ecosystem_packages = [path for path in ecosystem_packages if not (path / "pyproject.toml").exists()]
if missing_ecosystem_packages:
    raise RuntimeError(
        "Could not find local AbstractGraph ecosystem checkouts: "
        + ", ".join(str(path) for path in missing_ecosystem_packages)
    )

print(f"Installing local AbstractGraph ecosystem from {ecosystem_root}")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(ecosystem_packages[0])])
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(ecosystem_packages[1])])
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", ".[chem]"], cwd=ecosystem_packages[2])

print(f"Installing NodeField notebook dependencies from {repo_root}")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", "."], cwd=repo_root)
# Out:
# Installing local NSPPK checkout from /run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NSPPK
# WARNING: Cache entry deserialization failed, entry ignored
# Obtaining file:///run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NSPPK
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx>=3.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nsppk==0.1.0) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nsppk==0.1.0) (2.4.4)
# Requirement already satisfied: scipy>=1.10 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nsppk==0.1.0) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nsppk==0.1.0) (1.8.0)
# Requirement already satisfied: matplotlib>=3.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nsppk==0.1.0) (3.10.9)
# Collecting multiprocessing-on-dill>=3.5.0a4 (from nsppk==0.1.0)
#   Downloading multiprocessing_on_dill-3.5.0a4.tar.gz (53 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (26.2)
# Requirement already satisfied: pillow>=8 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (2.9.0.post0)
# Requirement already satisfied: dill in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from multiprocessing-on-dill>=3.5.0a4->nsppk==0.1.0) (0.4.1)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->nsppk==0.1.0) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from scikit-learn>=1.3->nsppk==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from scikit-learn>=1.3->nsppk==0.1.0) (3.6.0)
# Building wheels for collected packages: nsppk, multiprocessing-on-dill
#   Building editable for nsppk (pyproject.toml): started
#   Building editable for nsppk (pyproject.toml): finished with status 'done'
#   Created wheel for nsppk: filename=nsppk-0.1.0-0.editable-py3-none-any.whl size=5989 sha256=df259a7301b6eb0d2ccb9e1aebe61477571b3a252dad12f54dae3be7f9ecd89a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-oxkmxacs/wheels/12/50/16/01b918beed2e367508b10ca0fbdf430acaca9894513bba0b17
#   Building wheel for multiprocessing-on-dill (pyproject.toml): started
#   Building wheel for multiprocessing-on-dill (pyproject.toml): finished with status 'done'
#   Created wheel for multiprocessing-on-dill: filename=multiprocessing_on_dill-3.5.0a4-py3-none-any.whl size=64080 sha256=cc1698c2e29ff6ade979babc3f708f704c17e42b09a31ec323cf67219a06230f
#   Stored in directory: /home/fabrizio/.cache/pip/wheels/97/00/2f/13fb66678366c2f9d378889e8514b4292ad3148c0b81127b7f
# Successfully built nsppk multiprocessing-on-dill
# Installing collected packages: multiprocessing-on-dill, nsppk
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nsppk]
# Successfully installed multiprocessing-on-dill-3.5.0a4 nsppk-0.1.0
# Installing local AbstractGraph ecosystem from /run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/abstractgraph-ecosystem/repos
# Obtaining file:///run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/abstractgraph-ecosystem/repos/abstractgraph
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx>=3.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph==0.1.0) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph==0.1.0) (2.4.4)
# Requirement already satisfied: scipy>=1.10 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph==0.1.0) (1.17.1)
# Requirement already satisfied: joblib>=1.3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph==0.1.0) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph==0.1.0) (1.8.0)
# Requirement already satisfied: matplotlib>=3.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph==0.1.0) (3.10.9)
# Requirement already satisfied: toolz>=0.12 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph==0.1.0) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (26.2)
# Requirement already satisfied: pillow>=8 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->abstractgraph==0.1.0) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from scikit-learn>=1.3->abstractgraph==0.1.0) (3.6.0)
# Building wheels for collected packages: abstractgraph
#   Building editable for abstractgraph (pyproject.toml): started
#   Building editable for abstractgraph (pyproject.toml): finished with status 'done'
#   Created wheel for abstractgraph: filename=abstractgraph-0.1.0-0.editable-py3-none-any.whl size=2642 sha256=f34e4894b5bc951123712b6648f00677c15d303ecb7749a3d03b851211271b6c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cxpwir7j/wheels/6a/41/ff/9fd7da9bfac4d9722fb428410acd71ef490be7d0f85a5d9b5c
# Successfully built abstractgraph
# Installing collected packages: abstractgraph
# Successfully installed abstractgraph-0.1.0
# Obtaining file:///run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/abstractgraph-ecosystem/repos/abstractgraph-ml
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: abstractgraph>=0.1.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-ml==0.1.0) (0.1.0)
# Requirement already satisfied: matplotlib>=3.8 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-ml==0.1.0) (3.10.9)
# Requirement already satisfied: numpy>=1.24 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-ml==0.1.0) (2.4.4)
# Requirement already satisfied: pandas>=2.2 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-ml==0.1.0) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-ml==0.1.0) (1.8.0)
# Requirement already satisfied: networkx>=3.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (3.6.1)
# Requirement already satisfied: scipy>=1.10 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (1.17.1)
# Requirement already satisfied: joblib>=1.3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (1.5.3)
# Requirement already satisfied: toolz>=0.12 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (26.2)
# Requirement already satisfied: pillow>=8 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from pandas>=2.2->abstractgraph-ml==0.1.0) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from pandas>=2.2->abstractgraph-ml==0.1.0) (2026.2)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.8->abstractgraph-ml==0.1.0) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from scikit-learn>=1.3->abstractgraph-ml==0.1.0) (3.6.0)
# Building wheels for collected packages: abstractgraph-ml
#   Building editable for abstractgraph-ml (pyproject.toml): started
#   Building editable for abstractgraph-ml (pyproject.toml): finished with status 'done'
#   Created wheel for abstractgraph-ml: filename=abstractgraph_ml-0.1.0-0.editable-py3-none-any.whl size=2830 sha256=c6ea4b55a955dad6bea4ca572761d9f022aae01ff3f1003b8d15a84b0be08f28
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8rm171nc/wheels/be/7b/45/56383a21df193b0e515698328ceded5e0a193fc00fbb0508a2
# Successfully built abstractgraph-ml
# Installing collected packages: abstractgraph-ml
# Successfully installed abstractgraph-ml-0.1.0
# Obtaining file:///run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/abstractgraph-ecosystem/repos/abstractgraph-graphicalizer
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx>=3.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-graphicalizer==0.1.0) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-graphicalizer==0.1.0) (2.4.4)
# Requirement already satisfied: scipy>=1.11 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-graphicalizer==0.1.0) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-graphicalizer==0.1.0) (1.8.0)
# Requirement already satisfied: matplotlib>=3.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-graphicalizer==0.1.0) (3.10.9)
# Requirement already satisfied: Pillow>=10.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-graphicalizer==0.1.0) (12.2.0)
# Requirement already satisfied: requests>=2.31 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-graphicalizer==0.1.0) (2.34.2)
# Requirement already satisfied: torch>=2.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-graphicalizer==0.1.0) (2.12.0+cpu)
# Requirement already satisfied: rdkit>=2023.9.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from abstractgraph-graphicalizer==0.1.0) (2026.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (26.2)
# Requirement already satisfied: pyparsing>=3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from requests>=2.31->abstractgraph-graphicalizer==0.1.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from requests>=2.31->abstractgraph-graphicalizer==0.1.0) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from requests>=2.31->abstractgraph-graphicalizer==0.1.0) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from requests>=2.31->abstractgraph-graphicalizer==0.1.0) (2026.4.22)
# Requirement already satisfied: joblib>=1.3.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from scikit-learn>=1.3->abstractgraph-graphicalizer==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from scikit-learn>=1.3->abstractgraph-graphicalizer==0.1.0) (3.6.0)
# Requirement already satisfied: filelock in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (1.14.0)
# Requirement already satisfied: jinja2 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from sympy>=1.13.3->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from jinja2->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.0.3)
# Building wheels for collected packages: abstractgraph-graphicalizer
#   Building editable for abstractgraph-graphicalizer (pyproject.toml): started
#   Building editable for abstractgraph-graphicalizer (pyproject.toml): finished with status 'done'
#   Created wheel for abstractgraph-graphicalizer: filename=abstractgraph_graphicalizer-0.1.0-0.editable-py3-none-any.whl size=3078 sha256=c1f1339609dbd5e08cb834e8ef359861679201d4de2403473755b5db97861e4a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wvb42dez/wheels/64/b9/5c/5b6eb411487f7a75670f0b8ffcb4d0b47c99d497bacf6e5836
# Successfully built abstractgraph-graphicalizer
# Installing collected packages: abstractgraph-graphicalizer
# Successfully installed abstractgraph-graphicalizer-0.1.0
# Installing NodeField notebook dependencies from /run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NodeField
# Obtaining file:///run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NodeField
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy<3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nodefield==0.0.1) (2.4.4)
# Requirement already satisfied: torch in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nodefield==0.0.1) (2.12.0+cpu)
# Requirement already satisfied: scipy in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nodefield==0.0.1) (1.17.1)
# Requirement already satisfied: pandas in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nodefield==0.0.1) (2.3.3)
# Requirement already satisfied: scikit-learn in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nodefield==0.0.1) (1.8.0)
# Requirement already satisfied: networkx in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nodefield==0.0.1) (3.6.1)
# Requirement already satisfied: pulp in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nodefield==0.0.1) (3.3.1)
# Requirement already satisfied: dill in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from nodefield==0.0.1) (0.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from pandas->nodefield==0.0.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from pandas->nodefield==0.0.1) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from pandas->nodefield==0.0.1) (2026.2)
# Requirement already satisfied: six>=1.5 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->nodefield==0.0.1) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from scikit-learn->nodefield==0.0.1) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from scikit-learn->nodefield==0.0.1) (3.6.0)
# Requirement already satisfied: filelock in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch->nodefield==0.0.1) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch->nodefield==0.0.1) (4.15.0)
# Requirement already satisfied: setuptools<82 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch->nodefield==0.0.1) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch->nodefield==0.0.1) (1.14.0)
# Requirement already satisfied: jinja2 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch->nodefield==0.0.1) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from torch->nodefield==0.0.1) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from sympy>=1.13.3->torch->nodefield==0.0.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/fabrizio/.venvs/py314/lib/python3.14/site-packages (from jinja2->torch->nodefield==0.0.1) (3.0.3)
# Building wheels for collected packages: nodefield
#   Building editable for nodefield (pyproject.toml): started
#   Building editable for nodefield (pyproject.toml): finished with status 'done'
#   Created wheel for nodefield: filename=nodefield-0.0.1-0.editable-py3-none-any.whl size=8517 sha256=8e36161a84aa5badcb5d597b7733922406312e58c9d780c44e205dc27951bcd8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mmbnljhw/wheels/78/d0/c7/973b4b653622fc25d1e8969b4557fc9f23bbcb13dacc1a527e
# Successfully built nodefield
# Installing collected packages: nodefield
#   Attempting uninstall: nodefield
#     Found existing installation: nodefield 0.0.1
#     Not uninstalling nodefield at /run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NodeField, outside environment /home/fabrizio/.venvs/py314
#     Can't uninstall 'nodefield'. No files were found to uninstall.
# Successfully installed nodefield-0.0.1
# 0
