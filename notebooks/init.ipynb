# %% [markdown]
# # Notebook Init
#
# Run this notebook once per kernel before working with the demo notebooks.

# %%
import os
import subprocess
import sys
from pathlib import Path

repo_root = next(
    root for root in [Path.cwd(), *Path.cwd().parents]
    if (root / "conditional_node_field_graph_generator").exists()
)
nsppk_candidates = [
    repo_root.parent / "NSPPK",
    repo_root.parent / "nsppk",
]
local_nsppk_repo = next(
    (
        candidate.resolve()
        for candidate in nsppk_candidates
        if (candidate / "pyproject.toml").exists() or (candidate / "setup.py").exists()
    ),
    None,
)
if local_nsppk_repo is not None:
    print(f"Installing local NSPPK checkout from {local_nsppk_repo}")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(local_nsppk_repo)])
elif os.environ.get("NODEFIELD_SKIP_NSPPK") != "1":
    raise RuntimeError(
        "Could not find a local NSPPK checkout. Expected one of: "
        + ", ".join(str(path) for path in nsppk_candidates)
        + ". Set NODEFIELD_SKIP_NSPPK=1 only if the current notebook does not require NSPPK."
    )

ecosystem_root = repo_root.parent / "abstractgraph-ecosystem" / "repos"
ecosystem_packages = [
    ecosystem_root / "abstractgraph",
    ecosystem_root / "abstractgraph-ml",
    ecosystem_root / "abstractgraph-graphicalizer",
]
missing_ecosystem_packages = [path for path in ecosystem_packages if not (path / "pyproject.toml").exists()]
if missing_ecosystem_packages:
    raise RuntimeError(
        "Could not find local AbstractGraph ecosystem checkouts: "
        + ", ".join(str(path) for path in missing_ecosystem_packages)
    )

print(f"Installing local AbstractGraph ecosystem from {ecosystem_root}")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(ecosystem_packages[0])])
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", str(ecosystem_packages[1])])
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", ".[chem]"], cwd=ecosystem_packages[2])

print(f"Installing NodeField notebook dependencies from {repo_root}")
subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", "."], cwd=repo_root)
# Out:
# Installing local NSPPK checkout from /cs0eth/home/fc334/code/NSPPK
# Obtaining file:///cs0eth/home/fc334/code/NSPPK
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx>=3.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nsppk==0.1.0) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nsppk==0.1.0) (2.4.6)
# Requirement already satisfied: scipy>=1.10 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nsppk==0.1.0) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nsppk==0.1.0) (1.9.0)
# Requirement already satisfied: matplotlib>=3.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nsppk==0.1.0) (3.10.9)
# Requirement already satisfied: multiprocessing-on-dill>=3.5.0a4 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nsppk==0.1.0) (3.5.0a4)
# Requirement already satisfied: contourpy>=1.0.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (26.2)
# Requirement already satisfied: pillow>=8 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->nsppk==0.1.0) (2.9.0.post0)
# Requirement already satisfied: dill in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from multiprocessing-on-dill>=3.5.0a4->nsppk==0.1.0) (0.4.1)
# Requirement already satisfied: six>=1.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->nsppk==0.1.0) (1.17.0)
# Requirement already satisfied: joblib>=1.4.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->nsppk==0.1.0) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->nsppk==0.1.0) (2.22.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->nsppk==0.1.0) (3.6.0)
# Building wheels for collected packages: nsppk
#   Building editable for nsppk (pyproject.toml): started
#   Building editable for nsppk (pyproject.toml): finished with status 'done'
#   Created wheel for nsppk: filename=nsppk-0.1.0-0.editable-py3-none-any.whl size=5946 sha256=d6df4b4112158732a6cd9329a3f65385f783b4d3d70f37c2e3bb6d2fae3067fe
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ctltvrm1/wheels/3a/08/79/a3d752fcd2465f9f7870be515074fe5bf0720132fa8159a22d
# Successfully built nsppk
# Installing collected packages: nsppk
#   Attempting uninstall: nsppk
#     Found existing installation: nsppk 0.1.0
#     Uninstalling nsppk-0.1.0:
#       Successfully uninstalled nsppk-0.1.0
# Successfully installed nsppk-0.1.0
# Installing local AbstractGraph ecosystem from /cs0eth/home/fc334/code/abstractgraph-ecosystem/repos
# Obtaining file:///cs0eth/home/fc334/code/abstractgraph-ecosystem/repos/abstractgraph
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx>=3.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph==0.1.0) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph==0.1.0) (2.4.6)
# Requirement already satisfied: scipy>=1.10 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph==0.1.0) (1.17.1)
# Requirement already satisfied: joblib>=1.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph==0.1.0) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph==0.1.0) (1.9.0)
# Requirement already satisfied: matplotlib>=3.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph==0.1.0) (3.10.9)
# Requirement already satisfied: toolz>=0.12 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph==0.1.0) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (26.2)
# Requirement already satisfied: pillow>=8 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->abstractgraph==0.1.0) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->abstractgraph==0.1.0) (2.22.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->abstractgraph==0.1.0) (3.6.0)
# Building wheels for collected packages: abstractgraph
#   Building editable for abstractgraph (pyproject.toml): started
#   Building editable for abstractgraph (pyproject.toml): finished with status 'done'
#   Created wheel for abstractgraph: filename=abstractgraph-0.1.0-0.editable-py3-none-any.whl size=2609 sha256=0494b445a79bd5992df0ffcba4e9faa194685db55dacd20370e23168fe4420ee
#   Stored in directory: /tmp/pip-ephem-wheel-cache-soq0d1wh/wheels/60/f0/d6/762a9e3c106d9c0e5ab088a4a9c16e22cd8a68cbd3907ea9e4
# Successfully built abstractgraph
# Installing collected packages: abstractgraph
#   Attempting uninstall: abstractgraph
#     Found existing installation: abstractgraph 0.1.0
#     Uninstalling abstractgraph-0.1.0:
#       Successfully uninstalled abstractgraph-0.1.0
# Successfully installed abstractgraph-0.1.0
# Obtaining file:///cs0eth/home/fc334/code/abstractgraph-ecosystem/repos/abstractgraph-ml
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: abstractgraph>=0.1.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-ml==0.1.0) (0.1.0)
# Requirement already satisfied: matplotlib>=3.8 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-ml==0.1.0) (3.10.9)
# Requirement already satisfied: numpy>=1.24 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-ml==0.1.0) (2.4.6)
# Requirement already satisfied: pandas>=2.2 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-ml==0.1.0) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-ml==0.1.0) (1.9.0)
# Requirement already satisfied: networkx>=3.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (3.6.1)
# Requirement already satisfied: scipy>=1.10 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (1.17.1)
# Requirement already satisfied: joblib>=1.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (1.5.3)
# Requirement already satisfied: toolz>=0.12 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph>=0.1.0->abstractgraph-ml==0.1.0) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (26.2)
# Requirement already satisfied: pillow>=8 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.8->abstractgraph-ml==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.8->abstractgraph-ml==0.1.0) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->abstractgraph-ml==0.1.0) (2.22.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->abstractgraph-ml==0.1.0) (3.6.0)
# Building wheels for collected packages: abstractgraph-ml
#   Building editable for abstractgraph-ml (pyproject.toml): started
#   Building editable for abstractgraph-ml (pyproject.toml): finished with status 'done'
#   Created wheel for abstractgraph-ml: filename=abstractgraph_ml-0.1.0-0.editable-py3-none-any.whl size=2789 sha256=f5afd433f3ae5531ed754186723685d47b9203f7fe0b8b81cf63a4706307fdd9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x7hb_bln/wheels/ef/d8/29/4050fd8e7b0ce943fec830f1a9f749544692d65901dcf477e6
# Successfully built abstractgraph-ml
# Installing collected packages: abstractgraph-ml
#   Attempting uninstall: abstractgraph-ml
#     Found existing installation: abstractgraph-ml 0.1.0
#     Uninstalling abstractgraph-ml-0.1.0:
#       Successfully uninstalled abstractgraph-ml-0.1.0
# Successfully installed abstractgraph-ml-0.1.0
# Obtaining file:///cs0eth/home/fc334/code/abstractgraph-ecosystem/repos/abstractgraph-graphicalizer
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: networkx>=3.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-graphicalizer==0.1.0) (3.6.1)
# Requirement already satisfied: numpy>=1.24 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-graphicalizer==0.1.0) (2.4.6)
# Requirement already satisfied: scipy>=1.11 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-graphicalizer==0.1.0) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-graphicalizer==0.1.0) (1.9.0)
# Requirement already satisfied: matplotlib>=3.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-graphicalizer==0.1.0) (3.10.9)
# Requirement already satisfied: Pillow>=10.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-graphicalizer==0.1.0) (12.2.0)
# Requirement already satisfied: requests>=2.31 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-graphicalizer==0.1.0) (2.34.2)
# Requirement already satisfied: torch>=2.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-graphicalizer==0.1.0) (2.12.0)
# Requirement already satisfied: rdkit>=2023.9.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from abstractgraph-graphicalizer==0.1.0) (2026.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (26.2)
# Requirement already satisfied: pyparsing>=3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.7->abstractgraph-graphicalizer==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from requests>=2.31->abstractgraph-graphicalizer==0.1.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from requests>=2.31->abstractgraph-graphicalizer==0.1.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from requests>=2.31->abstractgraph-graphicalizer==0.1.0) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from requests>=2.31->abstractgraph-graphicalizer==0.1.0) (2026.5.20)
# Requirement already satisfied: joblib>=1.4.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->abstractgraph-graphicalizer==0.1.0) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->abstractgraph-graphicalizer==0.1.0) (2.22.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn>=1.3->abstractgraph-graphicalizer==0.1.0) (3.6.0)
# Requirement already satisfied: filelock in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (4.15.0)
# Requirement already satisfied: setuptools<82 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (1.14.0)
# Requirement already satisfied: jinja2 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (2026.4.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.7.0)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from jinja2->torch>=2.0->abstractgraph-graphicalizer==0.1.0) (3.0.3)
# Building wheels for collected packages: abstractgraph-graphicalizer
#   Building editable for abstractgraph-graphicalizer (pyproject.toml): started
#   Building editable for abstractgraph-graphicalizer (pyproject.toml): finished with status 'done'
#   Created wheel for abstractgraph-graphicalizer: filename=abstractgraph_graphicalizer-0.1.0-0.editable-py3-none-any.whl size=3039 sha256=a2cab078ce4c901465e6a5ad5fcf0801af26b9c28ef92894eee1325bcc026060
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bn_s9t6a/wheels/2d/28/6d/adffe886b403b06078986a389b67cf0d865f4af2cb9c4a9958
# Successfully built abstractgraph-graphicalizer
# Installing collected packages: abstractgraph-graphicalizer
#   Attempting uninstall: abstractgraph-graphicalizer
#     Found existing installation: abstractgraph-graphicalizer 0.1.0
#     Uninstalling abstractgraph-graphicalizer-0.1.0:
#       Successfully uninstalled abstractgraph-graphicalizer-0.1.0
# Successfully installed abstractgraph-graphicalizer-0.1.0
# Installing NodeField notebook dependencies from /cs0eth/home/fc334/code/NodeField
# Obtaining file:///cs0eth/home/fc334/code/NodeField
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy<3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nodefield==0.0.1) (2.4.6)
# Requirement already satisfied: torch in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nodefield==0.0.1) (2.12.0)
# Requirement already satisfied: scipy in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nodefield==0.0.1) (1.17.1)
# Requirement already satisfied: pandas in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nodefield==0.0.1) (3.0.3)
# Requirement already satisfied: scikit-learn in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nodefield==0.0.1) (1.9.0)
# Requirement already satisfied: networkx in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nodefield==0.0.1) (3.6.1)
# Requirement already satisfied: pulp in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nodefield==0.0.1) (3.3.2)
# Requirement already satisfied: dill in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from nodefield==0.0.1) (0.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from pandas->nodefield==0.0.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->nodefield==0.0.1) (1.17.0)
# Requirement already satisfied: joblib>=1.4.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn->nodefield==0.0.1) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn->nodefield==0.0.1) (2.22.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from scikit-learn->nodefield==0.0.1) (3.6.0)
# Requirement already satisfied: filelock in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (3.29.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (4.15.0)
# Requirement already satisfied: setuptools<82 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (1.14.0)
# Requirement already satisfied: jinja2 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (2026.4.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (13.0.2)
# Requirement already satisfied: nvidia-cublas<=13.1.1.3,>=13.1.0.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (13.1.1.3)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (13.3.1)
# Requirement already satisfied: nvidia-cudnn-cu13==9.20.0.48 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (9.20.0.48)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.1 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (0.8.1)
# Requirement already satisfied: nvidia-nccl-cu13==2.29.7 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (2.29.7)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (3.4.5)
# Requirement already satisfied: triton==3.7.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from torch->nodefield==0.0.1) (3.7.0)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-toolkit[cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch->nodefield==0.0.1) (13.0.85)
# Requirement already satisfied: cuda-pathfinder>=1.4.2 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch->nodefield==0.0.1) (1.5.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from sympy>=1.13.3->torch->nodefield==0.0.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /cs0eth/home/fc334/.local/share/mamba/envs/nodefield/lib/python3.11/site-packages (from jinja2->torch->nodefield==0.0.1) (3.0.3)
# Building wheels for collected packages: nodefield
#   Building editable for nodefield (pyproject.toml): started
#   Building editable for nodefield (pyproject.toml): finished with status 'done'
#   Created wheel for nodefield: filename=nodefield-0.0.1-0.editable-py3-none-any.whl size=8729 sha256=216e65b576da5b26a03f402e2f82f16a5abe29781aed50753b79864808d83152
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3v9zjr3z/wheels/95/2b/b8/aa19674c26e24affeeafb90cee9c3097d51a8bb35ecd598d23
# Successfully built nodefield
# Installing collected packages: nodefield
#   Attempting uninstall: nodefield
#     Found existing installation: nodefield 0.0.1
#     Uninstalling nodefield-0.0.1:
#       Successfully uninstalled nodefield-0.0.1
# Successfully installed nodefield-0.0.1
# 0
