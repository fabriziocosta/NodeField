# %% [markdown]
# # Monitor a campaign
#
# **Purpose:** Monitor a campaign.
#
# **Before you start:** Existing campaign state; Graphviz support for relationship diagrams. Use the Python environment prepared by [setup](../setup.ipynb).
#
# **Results:** Interactive campaign dashboard.
#
# Run the cells in order, reviewing the configuration before starting the main work. Data stays under `notebooks/datasets`; models and outputs use the project’s artifact folders.

# %% [markdown]
# Find the latest campaign and display its progress and experiment relationships.

# %%
print('Find the latest campaign and display its progress and experiment relationships.')
# %load_ext autoreload
# %autoreload 2

from conditional_node_field_graph_generator.notebooks import configure_notebook
globals().update(configure_notebook(require_nsppk=False, print_torch=False))

from conditional_node_field_graph_generator.extensions.demo.campaign_dashboard import display_latest_campaign_dashboard

display_latest_campaign_dashboard()
