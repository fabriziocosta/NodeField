# %% [markdown]
# # ZINC Molecule Hyperparameter Optimization
#
# YAML-driven random search for ZINC molecule generation, scored by average feasibility violations.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2

from IPython.display import display

from conditional_node_field_graph_generator.notebooks import configure_notebook

NOTEBOOK_CONTEXT = configure_notebook(require_nsppk=True, print_torch=True)
globals().update(NOTEBOOK_CONTEXT)

from abstractgraph_graphicalizer.chem import draw_molecules
from conditional_node_field_graph_generator.extensions.demo import (
    load_zinc_hyperparameter_optimization_config,
    run_zinc_hyperparameter_optimization,
    summarize_zinc_hyperparameter_results,
)
# Out:
# PyTorch version: 2.12.0+cpu
# CUDA available: False

# %%
CONFIG_PATH = REPO_ROOT / 'notebooks' / 'configs' / 'zinc_molecule_hyperparameter_optimization.yaml'
config = load_zinc_hyperparameter_optimization_config(CONFIG_PATH)

print(f'Config: {CONFIG_PATH}')
display(config)
# Out:
# Config: /run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NodeField/notebooks/configs/zinc_molecule_hyperparameter_optimization.yaml
# {'experiment': {'name': 'zinc_molecule_hyperparameter_optimization',
#   'n_trials': 3,
#   'random_state': 42,
#   'verbose': 1},
#  'dataset': {'num_graphs': 500,
#   'min_size': 4,
#   'max_size': 10,
#   'random_state': 42},
#  'model': {'fixed': {'nbits': 11,
#    'latent_embedding_dimension': 64,
#    'node_embedding_svd_dimension': 64,
#    'graph_embedding_svd_dimension': 64,
#    'number_of_transformer_layers': 2,
#    'transformer_attention_head_count': 4,
#    'transformer_dropout': 0.15,
#    'learning_rate': 0.0002,
#    'maximum_epochs': 80,
#    'batch_size': 16,
#    'total_steps': 80,
#    'verbose_epoch_interval': 10,
#    'enable_early_stopping': True,
#    'early_stopping_monitor': 'val_total',
#    'early_stopping_mode': 'min',
#    'early_stopping_patience': 15,
#    'early_stopping_min_delta': 5.0,
#    'restore_best_checkpoint': True,
#    'use_feasibility_filtering': True,
#    'feasibility_failure_mode': 'return_partial',
#    'decoder_enforce_connectivity': True,
#    'decoder_n_jobs': 1},
#   'search_space': {'lambda_degree_importance': {'type': 'real',
#     'low': 0.5,
#     'high': 4.0},
#    'lambda_node_exist_importance': {'type': 'real', 'low': 0.5, 'high': 4.0},
#    'lambda_node_count_importance': {'type': 'real', 'low': 0.0, 'high': 2.0},
#    'lambda_node_label_importance': {'type': 'real', 'low': 0.5, 'high': 4.0},
#    'lambda_edge_label_importance': {'type': 'real', 'low': 0.5, 'high': 4.0},
#    'lambda_direct_edge_importance': {'type': 'real', 'low': 0.5, 'high': 4.0},
#    'lambda_auxiliary_edge_importance': {'type': 'real',
#     'low': 0.5,
#     'high': 4.0},
#    'sparse_supervision_mask_ratio': {'type': 'real', 'low': 0.0, 'high': 0.5},
#    'sampling_step_size': {'type': 'real', 'low': 0.02, 'high': 0.08}}},
#  'generation': {'n_samples': 16,
#   'feasibility_effort': 3,
#   'feasibility_filter': 'strict'},
#  'outputs': {'artifact_subdir': 'zinc_molecule_hyperparameter_optimization',
#   'results_csv': 'trial_results.csv'}}

# %%
# %%time
result = run_zinc_hyperparameter_optimization(config, notebook_context=NOTEBOOK_CONTEXT)

print(f"Artifacts: {result['artifact_root']}")
if result['results_csv_path'] is not None:
    print(f"Results CSV: {result['results_csv_path']}")
# Out:
# No checkpoint selected for resume; training will start from scratch.
# Fitting model on 290 graphs
# Fitting graph vectorizer on 290 graphs
# Finished fitting graph vectorizer on 290 graphs in 0m 0.0s
# Fitting node graph vectorizer on 290 graphs
# Finished fitting node graph vectorizer on 290 graphs in 0m 0.0s
# Encoding node embeddings for 290 graphs
# Finished encoding node embeddings for 290 graphs in 0m 1.6s
# Encoding graph embeddings for 290 graphs
# Finished encoding graph embeddings for 290 graphs in 0m 1.4s
# Fitting embedding SVDs
# Stacking raw node embeddings for SVD.
# Stacked node embedding matrix: shape=(2769, 2048), sparse=True, nnz=400567, density=0.070635.
# Prepared graph embedding matrix: shape=(290, 2048), sparse=True, nnz=199245, density=0.335474.
# Fitting node embedding SVD on shape=(2769, 2048), sparse=True, nnz=400567, density=0.070635 to 64 dimensions.
# Fitted node embedding SVD: 2048 -> 64.
# Fitting graph embedding SVD on shape=(290, 2048), sparse=True, nnz=199245, density=0.335474 to 64 dimensions.
# Fitted graph embedding SVD: 2048 -> 64.
# Finished fitting embedding SVDs in 0m 2.3s
# Fitting feasibility estimator on 290 graphs
# Finished fitting feasibility estimator on 290 graphs in 0m 7.4s
# Building node-label targets for 290 graphs
# Finished building node-label targets for 290 graphs in 0m 0.0s
# Building edge-label targets for 290 graphs
# Finished building edge-label targets for 290 graphs in 0m 0.0s
# Building supervision plan
# Finished building supervision plan in 0m 0.0s
# Compressing node embeddings for 290 graphs
# Finished compressing node embeddings for 290 graphs in 0m 0.1s
# Building graph conditioning for 290 graphs
# Finished building graph conditioning for 290 graphs in 0m 0.0s
# Supervision plan:
#   node_labels: mode=learned, enabled. 9 node labels detected.
#   edge_labels: mode=learned, enabled. 4 edge labels detected.
#   direct_edges: mode=learned, enabled, horizon=1. Generator should learn horizon-1 edge presence for the decoder.
#   auxiliary_locality: mode=learned, enabled, horizon=3. Use horizon-3 locality as auxiliary regularization.
# adj_mtx_to_targets[direct_edge, horizon=1]: sampling 15837 pairs (50.00%) from 31674 total pairs (pos=10860, neg=20814, negative_sample_factor=1, sampling_strategy=stratified_preserve, target_positive_ratio=0.500).
# adj_mtx_to_targets[direct_edge, horizon=1]: using pos=5430, neg=10407, positive_ratio=0.343.
# adj_mtx_to_targets[aux_locality, horizon=3]: sampling 23840 pairs (50.00%) from 47680 total pairs (pos=36096, neg=11584, negative_sample_factor=1, sampling_strategy=stratified_preserve, target_positive_ratio=0.500).
# adj_mtx_to_targets[aux_locality, horizon=3]: using pos=18048, neg=5792, positive_ratio=0.757.
# Training conditional model on 290 graphs with up to 10 nodes each.
# Using direct-edge supervision with 15837 labelled pairs.
# Lambda settings: degree=2.783, node_exist=0.653, node_count=0.040, node_label=3.437, edge_label=2.555, direct_edge=1.286, edge_count=0.500, deg_edge_consistency=0.500, aux_edge=3.131
# Direct edge supervision enabled: horizon-1 edge presence will be learned and used by the decoder.
# Soft edge-count supervision enabled: lambda_edge_count_importance=0.500.
# Soft node-count supervision enabled: lambda_node_count_importance=0.040.
# Degree/edge-count consistency supervision enabled: lambda_degree_edge_consistency_importance=0.500.
# Auxiliary locality supervision enabled: higher-horizon locality pairs will be used only as an encoding regularizer.
# Edge-label supervision enabled: discrete edge labels will be predicted by the generator.
# Direct-edge BCE positive weight: 1.917.
# Auxiliary-locality BCE positive weight: 1.000.
# ANN size: parameters=246,870, trainable=246,870, parameter_size=0.99 MB, trainable_size=0.99 MB.
# Writing checkpoints to /run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NodeField/.artifacts/zinc_molecule_hyperparameter_optimization/trial_001/checkpoints/ConditionalNodeFieldGenerator_1a401d50e6bd41d98b20b80c7791baca
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# /home/fabrizio/.venvs/py314/lib/python3.14/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Epoch 10/80 | ETA 1h 02m 45s:
#   train total=   40.330 | node_field    23.886 [59.2%] |        deg    2.5096 [6.2%] |      exist   0.06403 [0.2%] | node_count   0.00009 [<0.1%]
#   val   total=   39.611 | node_field    23.878 [60.3%] |        deg    2.4854 [6.3%] |      exist   0.04520 [0.1%] | node_count   0.00004 [<0.1%]
#   train                 | node_label    3.0528 [7.6%] | edge_label    1.6114 [4.0%] |       edge    1.1505 [2.9%] | edge_count    6.4144 [15.9%] | deg_edge_consistency   0.00104 [<0.1%]
#   val                   | node_label    2.8654 [7.2%] | edge_label    1.3803 [3.5%] |       edge    1.1654 [2.9%] | edge_count    6.1823 [15.6%] | deg_edge_consistency   0.00071 [<0.1%]
#   train                 |        aux    1.6398 [4.1%] | dominant=node_field [59.2%]
#   val                   |        aux    1.6083 [4.1%] | dominant=node_field [60.3%]
# Epoch 20/80 | ETA 0h 53m 30s:
#   train total=   37.530 | node_field    23.392 [62.3%] |        deg    2.1772 [5.8%] |      exist   0.04278 [0.1%] | node_count   0.00007 [<0.1%]
#   val   total=   36.794 | node_field    22.716 [61.7%] |        deg    2.0389 [5.5%] |      exist   0.02820 [<0.1%] | node_count   0.00002 [<0.1%]
#   train                 | node_label    2.0126 [5.4%] | edge_label    1.2598 [3.4%] |       edge    1.1372 [3.0%] | edge_count    5.9174 [15.8%] | deg_edge_consistency   0.00094 [<0.1%]
#   val                   | node_label    1.9800 [5.4%] | edge_label    1.2145 [3.3%] |       edge    1.1365 [3.1%] | edge_count    6.1080 [16.6%] | deg_edge_consistency   0.00064 [<0.1%]
#   train                 |        aux    1.5897 [4.2%] | dominant=node_field [62.3%]
#   val                   |        aux    1.5712 [4.3%] | dominant=node_field [61.7%]
# Restored best checkpoint: best_epoch=20, val_total=36.7936, raw_val_node_field=22.8623, stopped_epoch=24
#   path=/run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NodeField/.artifacts/zinc_molecule_hyperparameter_optimization/trial_001/checkpoints/ConditionalNodeFieldGenerator_1a401d50e6bd41d98b20b80c7791baca/best-019-36.7936.ckpt
# Feasibility attempt  1/8  | generated=   3 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=1m 20.1s | eta=9m 21.0s
# Feasibility attempt  2/8  | generated=   3 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=1m 22.2s | eta=8m 07.1s
# Feasibility effort failed; retrying lower-effort fallbacks (effort=3, error=Process-based parallel adjacency decode exceeded 9.0s.).
# Feasibility effort returned no graphs; retrying same sampled conditioning at lower effort(s) (1, 0).
# Feasibility attempt  1/1  | generated=   1 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=   32.7s | eta=    0.0s
# Feasibility filtering summary: generated=1, feasible_candidates=0, feasible_rate=0.0%, fulfilled_slots=0/1.
# Feasibility attempt  1/1  | generated=   1 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=   33.0s | eta=    0.0s
# Feasibility filtering summary: generated=1, feasible_candidates=0, feasible_rate=0.0%, fulfilled_slots=0/1.
# Feasibility attempt  1/1  | generated=   1 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=   32.9s | eta=    0.0s
# Feasibility filtering summary: generated=1, feasible_candidates=0, feasible_rate=0.0%, fulfilled_slots=0/1.
# Lower-effort fallback failed; continuing fallback chain (effort=1, error=Process-based parallel adjacency decode exceeded 2.0s.).
# Effort 1 fallback returned no graphs; retrying effort 0 direct edge-threshold decoding.
# No checkpoint selected for resume; training will start from scratch.
# Fitting model on 290 graphs
# Fitting graph vectorizer on 290 graphs
# Finished fitting graph vectorizer on 290 graphs in 0m 0.0s
# Fitting node graph vectorizer on 290 graphs
# Finished fitting node graph vectorizer on 290 graphs in 0m 0.0s
# Encoding node embeddings for 290 graphs
# Finished encoding node embeddings for 290 graphs in 0m 2.0s
# Encoding graph embeddings for 290 graphs
# Finished encoding graph embeddings for 290 graphs in 0m 1.9s
# Fitting embedding SVDs
# Stacking raw node embeddings for SVD.
# Stacked node embedding matrix: shape=(2769, 2048), sparse=True, nnz=400567, density=0.070635.
# Prepared graph embedding matrix: shape=(290, 2048), sparse=True, nnz=199245, density=0.335474.
# Fitting node embedding SVD on shape=(2769, 2048), sparse=True, nnz=400567, density=0.070635 to 64 dimensions.
# Fitted node embedding SVD: 2048 -> 64.
# Fitting graph embedding SVD on shape=(290, 2048), sparse=True, nnz=199245, density=0.335474 to 64 dimensions.
# Fitted graph embedding SVD: 2048 -> 64.
# Finished fitting embedding SVDs in 0m 2.1s
# Fitting feasibility estimator on 290 graphs
# Finished fitting feasibility estimator on 290 graphs in 0m 8.5s
# Building node-label targets for 290 graphs
# Finished building node-label targets for 290 graphs in 0m 0.0s
# Building edge-label targets for 290 graphs
# Finished building edge-label targets for 290 graphs in 0m 0.0s
# Building supervision plan
# Finished building supervision plan in 0m 0.0s
# Compressing node embeddings for 290 graphs
# Finished compressing node embeddings for 290 graphs in 0m 0.1s
# Building graph conditioning for 290 graphs
# Finished building graph conditioning for 290 graphs in 0m 0.0s
# Supervision plan:
#   node_labels: mode=learned, enabled. 9 node labels detected.
#   edge_labels: mode=learned, enabled. 4 edge labels detected.
#   direct_edges: mode=learned, enabled, horizon=1. Generator should learn horizon-1 edge presence for the decoder.
#   auxiliary_locality: mode=learned, enabled, horizon=3. Use horizon-3 locality as auxiliary regularization.
# adj_mtx_to_targets[direct_edge, horizon=1]: sampling 15837 pairs (50.00%) from 31674 total pairs (pos=10860, neg=20814, negative_sample_factor=1, sampling_strategy=stratified_preserve, target_positive_ratio=0.500).
# adj_mtx_to_targets[direct_edge, horizon=1]: using pos=5430, neg=10407, positive_ratio=0.343.
# adj_mtx_to_targets[aux_locality, horizon=3]: sampling 23840 pairs (50.00%) from 47680 total pairs (pos=36096, neg=11584, negative_sample_factor=1, sampling_strategy=stratified_preserve, target_positive_ratio=0.500).
# adj_mtx_to_targets[aux_locality, horizon=3]: using pos=18048, neg=5792, positive_ratio=0.757.
# Training conditional model on 290 graphs with up to 10 nodes each.
# Using direct-edge supervision with 15837 labelled pairs.
# Lambda settings: degree=0.929, node_exist=1.403, node_count=0.812, node_label=3.892, edge_label=1.068, direct_edge=3.501, edge_count=0.500, deg_edge_consistency=0.500, aux_edge=1.071
# Direct edge supervision enabled: horizon-1 edge presence will be learned and used by the decoder.
# Soft edge-count supervision enabled: lambda_edge_count_importance=0.500.
# Soft node-count supervision enabled: lambda_node_count_importance=0.812.
# Degree/edge-count consistency supervision enabled: lambda_degree_edge_consistency_importance=0.500.
# Auxiliary locality supervision enabled: higher-horizon locality pairs will be used only as an encoding regularizer.
# Edge-label supervision enabled: discrete edge labels will be predicted by the generator.
# Direct-edge BCE positive weight: 1.917.
# Auxiliary-locality BCE positive weight: 1.000.
# ANN size: parameters=246,870, trainable=246,870, parameter_size=0.99 MB, trainable_size=0.99 MB.
# Writing checkpoints to /run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NodeField/.artifacts/zinc_molecule_hyperparameter_optimization/trial_002/checkpoints/ConditionalNodeFieldGenerator_82f405505e014cce900dc1ee7e32de80
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# /home/fabrizio/.venvs/py314/lib/python3.14/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Epoch 10/80 | ETA 1h 04m 54s:
#   train total=   38.970 | node_field    23.702 [60.8%] |        deg   0.94645 [2.4%] |      exist   0.08042 [0.2%] | node_count   0.00103 [<0.1%]
#   val   total=   38.261 | node_field    23.192 [60.6%] |        deg   0.82916 [2.2%] |      exist   0.06840 [0.2%] | node_count   0.00103 [<0.1%]
#   train                 | node_label    3.1940 [8.2%] | edge_label   0.73781 [1.9%] |       edge    3.1561 [8.1%] | edge_count    6.5849 [16.9%] | deg_edge_consistency   0.00107 [<0.1%]
#   val                   | node_label    2.6803 [7.0%] | edge_label   0.65295 [1.7%] |       edge    3.1108 [8.1%] | edge_count    7.1699 [18.7%] | deg_edge_consistency   0.00079 [<0.1%]
#   train                 |        aux   0.56588 [1.5%] | dominant=node_field [60.8%]
#   val                   |        aux   0.55571 [1.5%] | dominant=node_field [60.6%]
# Epoch 20/80 | ETA 0h 54m 29s:
#   train total=   36.999 | node_field    23.320 [63.0%] |        deg   0.82135 [2.2%] |      exist   0.05803 [0.2%] | node_count   0.00113 [<0.1%]
#   val   total=   37.452 | node_field    23.538 [62.8%] |        deg   0.78260 [2.1%] |      exist   0.05439 [0.1%] | node_count   0.00111 [<0.1%]
#   train                 | node_label    2.0198 [5.5%] | edge_label   0.64648 [1.7%] |       edge    3.0967 [8.4%] | edge_count    6.4879 [17.5%] | deg_edge_consistency   0.00096 [<0.1%]
#   val                   | node_label    2.2973 [6.1%] | edge_label   0.62705 [1.7%] |       edge    3.0944 [8.3%] | edge_count    6.4830 [17.3%] | deg_edge_consistency   0.00066 [<0.1%]
#   train                 |        aux   0.54736 [1.5%] | dominant=node_field [63.0%]
#   val                   |        aux   0.57325 [1.5%] | dominant=node_field [62.8%]
# Restored best checkpoint: best_epoch=21, val_total=35.6317, raw_val_node_field=23.5380, stopped_epoch=26
#   path=/run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NodeField/.artifacts/zinc_molecule_hyperparameter_optimization/trial_002/checkpoints/ConditionalNodeFieldGenerator_82f405505e014cce900dc1ee7e32de80/best-020-35.6317.ckpt
# Feasibility attempt  1/8  | generated=   3 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=1m 17.1s | eta=9m 00.0s
# Feasibility attempt  2/8  | generated=   3 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=1m 22.5s | eta=7m 58.9s
# Feasibility effort failed; retrying lower-effort fallbacks (effort=3, error=Process-based parallel adjacency decode exceeded 9.0s.).
# Feasibility effort returned no graphs; retrying same sampled conditioning at lower effort(s) (1, 0).
# Feasibility attempt  1/1  | generated=   1 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=   31.9s | eta=    0.0s
# Feasibility filtering summary: generated=1, feasible_candidates=0, feasible_rate=0.0%, fulfilled_slots=0/1.
# Feasibility attempt  1/1  | generated=   1 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=   32.0s | eta=    0.0s
# Feasibility filtering summary: generated=1, feasible_candidates=0, feasible_rate=0.0%, fulfilled_slots=0/1.
# Feasibility attempt  1/1  | generated=   1 | feasible_candidates= 0 | feasible_rate=  0.0% | attempt_time=   34.5s | eta=    0.0s
# Feasibility filtering summary: generated=1, feasible_candidates=0, feasible_rate=0.0%, fulfilled_slots=0/1.
# Lower-effort fallback failed; continuing fallback chain (effort=1, error=Process-based parallel adjacency decode exceeded 2.0s.).
# Effort 1 fallback returned no graphs; retrying effort 0 direct edge-threshold decoding.
# No checkpoint selected for resume; training will start from scratch.
# Fitting model on 290 graphs
# Fitting graph vectorizer on 290 graphs
# Finished fitting graph vectorizer on 290 graphs in 0m 0.0s
# Fitting node graph vectorizer on 290 graphs
# Finished fitting node graph vectorizer on 290 graphs in 0m 0.0s
# Encoding node embeddings for 290 graphs
# Finished encoding node embeddings for 290 graphs in 0m 2.2s
# Encoding graph embeddings for 290 graphs
# Finished encoding graph embeddings for 290 graphs in 0m 2.2s
# Fitting embedding SVDs
# Stacking raw node embeddings for SVD.
# Stacked node embedding matrix: shape=(2769, 2048), sparse=True, nnz=400567, density=0.070635.
# Prepared graph embedding matrix: shape=(290, 2048), sparse=True, nnz=199245, density=0.335474.
# Fitting node embedding SVD on shape=(2769, 2048), sparse=True, nnz=400567, density=0.070635 to 64 dimensions.
# Fitted node embedding SVD: 2048 -> 64.
# Fitting graph embedding SVD on shape=(290, 2048), sparse=True, nnz=199245, density=0.335474 to 64 dimensions.
# Fitted graph embedding SVD: 2048 -> 64.
# Finished fitting embedding SVDs in 0m 1.7s
# Fitting feasibility estimator on 290 graphs
# Finished fitting feasibility estimator on 290 graphs in 0m 9.1s
# Building node-label targets for 290 graphs
# Finished building node-label targets for 290 graphs in 0m 0.0s
# Building edge-label targets for 290 graphs
# Finished building edge-label targets for 290 graphs in 0m 0.0s
# Building supervision plan
# Finished building supervision plan in 0m 0.0s
# Compressing node embeddings for 290 graphs
# Finished compressing node embeddings for 290 graphs in 0m 0.1s
# Building graph conditioning for 290 graphs
# Finished building graph conditioning for 290 graphs in 0m 0.0s
# Supervision plan:
#   node_labels: mode=learned, enabled. 9 node labels detected.
#   edge_labels: mode=learned, enabled. 4 edge labels detected.
#   direct_edges: mode=learned, enabled, horizon=1. Generator should learn horizon-1 edge presence for the decoder.
#   auxiliary_locality: mode=learned, enabled, horizon=3. Use horizon-3 locality as auxiliary regularization.
# adj_mtx_to_targets[direct_edge, horizon=1]: sampling 15837 pairs (50.00%) from 31674 total pairs (pos=10860, neg=20814, negative_sample_factor=1, sampling_strategy=stratified_preserve, target_positive_ratio=0.500).
# adj_mtx_to_targets[direct_edge, horizon=1]: using pos=5430, neg=10407, positive_ratio=0.343.
# adj_mtx_to_targets[aux_locality, horizon=3]: sampling 23840 pairs (50.00%) from 47680 total pairs (pos=36096, neg=11584, negative_sample_factor=1, sampling_strategy=stratified_preserve, target_positive_ratio=0.500).
# adj_mtx_to_targets[aux_locality, horizon=3]: using pos=18048, neg=5792, positive_ratio=0.757.
# Training conditional model on 290 graphs with up to 10 nodes each.
# Using direct-edge supervision with 15837 labelled pairs.
# Lambda settings: degree=2.506, node_exist=2.350, node_count=1.527, node_label=3.341, edge_label=2.286, direct_edge=3.228, edge_count=0.500, deg_edge_consistency=0.500, aux_edge=3.286
# Direct edge supervision enabled: horizon-1 edge presence will be learned and used by the decoder.
# Soft edge-count supervision enabled: lambda_edge_count_importance=0.500.
# Soft node-count supervision enabled: lambda_node_count_importance=1.527.
# Degree/edge-count consistency supervision enabled: lambda_degree_edge_consistency_importance=0.500.
# Auxiliary locality supervision enabled: higher-horizon locality pairs will be used only as an encoding regularizer.
# Edge-label supervision enabled: discrete edge labels will be predicted by the generator.
# Direct-edge BCE positive weight: 1.917.
# Auxiliary-locality BCE positive weight: 1.000.
# ANN size: parameters=246,870, trainable=246,870, parameter_size=0.99 MB, trainable_size=0.99 MB.
# Writing checkpoints to /run/media/fabrizio/06bb7271-2161-43a4-91f1-98f9b67e9ab2/home/fabrizio/code/NodeField/.artifacts/zinc_molecule_hyperparameter_optimization/trial_003/checkpoints/ConditionalNodeFieldGenerator_d77c9f3c96d84bc4b331c40388ece851
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# /home/fabrizio/.venvs/py314/lib/python3.14/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Epoch 10/80 | ETA 1h 04m 27s:
#   train total=   42.194 | node_field    23.724 [56.2%] |        deg    2.2709 [5.4%] |      exist   0.11083 [0.3%] | node_count   0.00178 [<0.1%]
#   val   total=   40.759 | node_field    23.537 [57.7%] |        deg    2.3135 [5.7%] |      exist   0.12255 [0.3%] | node_count   0.00371 [<0.1%]
#   train                 | node_label    3.1781 [7.5%] | edge_label    1.5235 [3.6%] |       edge    2.9130 [6.9%] | edge_count    6.7463 [16.0%] | deg_edge_consistency   0.00137 [<0.1%]
#   val                   | node_label    2.8878 [7.1%] | edge_label    1.3887 [3.4%] |       edge    2.8297 [6.9%] | edge_count    5.9785 [14.7%] | deg_edge_consistency   0.00095 [<0.1%]
#   train                 |        aux    1.7239 [4.1%] | dominant=node_field [56.2%]
#   val                   |        aux    1.6960 [4.2%] | dominant=node_field [57.7%]

# %%
results_df = summarize_zinc_hyperparameter_results(result)
display(results_df)

best_row = result['best_row']
display(best_row)

# %%
best_samples = result['best_samples']
best_violations = result['best_violation_counts']

if best_samples:
    draw_molecules(
        best_samples,
        legends=[f'#violations={int(v)}' for v in best_violations],
    )
else:
    print('Best trial returned no generated molecules.')
