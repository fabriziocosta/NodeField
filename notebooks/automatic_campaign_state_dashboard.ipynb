# %% [markdown]
# # Automatic Campaign State Dashboard
#
# This notebook automatically discovers the newest scientific campaign state under `artifact/`, shows what experiment is currently running or was most recently completed, and lets you inspect observations, hypotheses, beliefs, questions, candidates, and their Graphviz relations at detail levels 0–3. Visible labels stay compact (`E001`, `O001`, `H001`, …); hover them for the full text.

# %%
# %load_ext autoreload
# %autoreload 2

from conditional_node_field_graph_generator.notebooks import configure_notebook
globals().update(configure_notebook(require_nsppk=False, print_torch=False))

from conditional_node_field_graph_generator.extensions.demo.campaign_dashboard import display_latest_campaign_dashboard

display_latest_campaign_dashboard()
