# %% [markdown]
# # ZINC Generation Demo
#
# This notebook is the maintained ZINC-focused Conditional Node Field demo.
#
# It downloads a large ZINC molecular table once, caches the converted NetworkX molecular graphs on disk, and lets you resume later without rebuilding the dataset or retraining the generator.

# %%
# Enable inline plotting and autoreload for ZINC exploration.
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import torch
from IPython.core.display import HTML
from sklearn.model_selection import train_test_split

HTML('<style>.container { width:95% !important; }</style><style>.output_png {display: table-cell; text-align: center; vertical-align: middle;}</style>')

from conditional_node_field_graph_generator.notebooks import configure_notebook

globals().update(configure_notebook(require_nsppk=True, print_torch=True))

from conditional_node_field_graph_generator.extensions.demo import show_molecules
from conditional_node_field_graph_generator.extensions.demo.pipeline import (
    build_graph_generator,
    prepare_zinc_data_split,
    fit_graph_generator,
)
from conditional_node_field_graph_generator.extensions.demo.storage import (
    find_latest_checkpoint,
    list_training_checkpoints,
)
from abstractgraph_graphicalizer.chem import (
    draw_molecules,
    smiles_to_graph,
)
from conditional_node_field_graph_generator.persistence import (
    list_saved_graph_generators,
    load_graph_generator,
    save_graph_generator,
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# PyTorch version: 2.10.0+cpu
# CUDA available: False

# %% [markdown]
# ## Helpers
#
# The helper cell below keeps the molecule display and sampling utilities local to this notebook, including a simple endpoint sampler for interpolation experiments.

# %%
# Import display and summary utilities.


def label_counter(graphs, kind="node"):
    counts = {}
    if kind == "node":
        for graph in graphs:
            for _, attrs in graph.nodes(data=True):
                label = attrs.get("label")
                counts[label] = counts.get(label, 0) + 1
    elif kind == "edge":
        for graph in graphs:
            for _, _, attrs in graph.edges(data=True):
                label = attrs.get("label")
                counts[label] = counts.get(label, 0) + 1
    else:
        raise ValueError("kind must be 'node' or 'edge'")
    return dict(sorted(counts.items(), key=lambda item: str(item[0])))


def summarize_graphs(graphs, prefix="dataset"):
    node_counts = np.array([graph.number_of_nodes() for graph in graphs], dtype=int)
    edge_counts = np.array([graph.number_of_edges() for graph in graphs], dtype=int)
    print(f"{prefix}: {len(graphs)} graphs")
    print(
        f"{prefix}: node count min/median/max = "
        f"{node_counts.min()}/{int(np.median(node_counts))}/{node_counts.max()}"
    )
    print(
        f"{prefix}: edge count min/median/max = "
        f"{edge_counts.min()}/{int(np.median(edge_counts))}/{edge_counts.max()}"
    )
    print(f"{prefix}: node labels = {label_counter(graphs, 'node')}")
    print(f"{prefix}: edge labels = {label_counter(graphs, 'edge')}")


def show_seed_and_samples(
    graph_generator,
    seed_graphs,
    n_seeds=6,
    title="Samples",
    apply_feasibility_filtering=None,
    feasibility_oracle_candidates_per_attempt=None,
):
    # Show conditioning molecules first, then raw decoded samples, then feasibility-filtered samples.
    if apply_feasibility_filtering is None:
        apply_feasibility_filtering = APPLY_FEASIBILITY_FILTERING
    if feasibility_oracle_candidates_per_attempt is None:
        feasibility_oracle_candidates_per_attempt = FEASIBILITY_ORACLE_CANDIDATES_PER_ATTEMPT
    feasibility_estimator = getattr(graph_generator, "feasibility_estimator", None)
    if feasibility_estimator is None:
        if apply_feasibility_filtering or feasibility_oracle_candidates_per_attempt:
            print("Feasibility support is unavailable for this graph generator; sampling without feasibility filtering or oracle.")
        apply_feasibility_filtering = False
        feasibility_oracle_candidates_per_attempt = 0
    else:
        feasibility_estimator.set_parallel(False)
    seed_graphs = list(seed_graphs)[:n_seeds]
    show_molecules(seed_graphs, n=n_seeds, title=f"{title}: conditioning molecules")

    raw_samples = graph_generator.sample_conditioned_on_random(
        seed_graphs,
        n_samples=n_seeds,
        apply_feasibility_filtering=False,
        feasibility_oracle_candidates_per_attempt=feasibility_oracle_candidates_per_attempt,
    )
    show_molecules(raw_samples, n=n_seeds, title=f"{title}: generated molecules without feasibility")

    if not apply_feasibility_filtering:
        return raw_samples

    feasible_samples = graph_generator.sample_conditioned_on_random(
        seed_graphs,
        n_samples=n_seeds,
        apply_feasibility_filtering=True,
        feasibility_oracle_candidates_per_attempt=feasibility_oracle_candidates_per_attempt,
    )
    show_molecules(feasible_samples, n=n_seeds, title=f"{title}: generated molecules with feasibility")
    return feasible_samples


def inspect_predicted_masks_and_edge_labels(graph_generator, graphs, n_graphs=6):
    # Inspect raw node masks, decoder-aligned support sizes, and edge totals before full analysis.
    graph_conditioning = graph_generator.graph_encode(list(graphs)[:n_graphs])
    generated_nodes = graph_generator.conditional_node_generator_model.predict(graph_conditioning)

    decoded = graph_generator.graph_decoder.decode(
        generated_nodes,
        predicted_node_labels_list=generated_nodes.node_labels,
        predicted_edge_probability_matrices=generated_nodes.edge_probability_matrices,
        predicted_edge_label_matrices=generated_nodes.edge_label_matrices,
        desired_node_counts=graph_conditioning.node_counts[:n_graphs],
        desired_edge_counts=graph_conditioning.edge_counts[:n_graphs],
    )

    observed_node_counts = graph_conditioning.node_counts[:n_graphs]
    raw_predicted_node_counts = generated_nodes.node_presence_mask[:n_graphs].sum(axis=1)
    decoded_support_node_counts = []
    raw_expected_edge_counts = []
    decoded_edge_counts = []
    for idx in range(min(n_graphs, len(decoded))):
        raw_mask = np.asarray(generated_nodes.node_presence_mask[idx], dtype=bool)
        existence_scores = None if generated_nodes.node_existence_probabilities is None else np.asarray(
            generated_nodes.node_existence_probabilities[idx],
            dtype=float,
        )
        decoded_support_mask = graph_generator.graph_decoder.resolve_node_presence_mask(
            raw_mask,
            desired_node_count=int(observed_node_counts[idx]),
            node_existence_scores=existence_scores,
        )
        decoded_support_node_counts.append(int(decoded_support_mask.sum()))
        if generated_nodes.edge_probability_matrices is None:
            raw_expected_edge_counts.append(np.nan)
        else:
            prob_matrix = np.asarray(generated_nodes.edge_probability_matrices[idx], dtype=float)
            active_prob_matrix = prob_matrix[: raw_mask.shape[0], : raw_mask.shape[0]].copy()
            active_prob_matrix[~decoded_support_mask, :] = 0.0
            active_prob_matrix[:, ~decoded_support_mask] = 0.0
            raw_expected_edge_counts.append(float(np.triu(active_prob_matrix, k=1).sum()))
        decoded_edge_counts.append(int(decoded[idx].number_of_edges()))
    mask_frame = pd.DataFrame(
        {
            "conditioning_nodes": observed_node_counts,
            "raw_predicted_nodes": raw_predicted_node_counts,
            "decoded_support_nodes": decoded_support_node_counts,
            "conditioning_edges": graph_conditioning.edge_counts[:n_graphs],
            "raw_expected_edges": raw_expected_edge_counts,
            "decoded_edges": decoded_edge_counts,
        }
    )
    display(mask_frame)

    edge_label_matrices = generated_nodes.edge_label_matrices
    if edge_label_matrices is None:
        print("No edge-label matrices were predicted.")
    else:
        summaries = []
        for idx, matrix in enumerate(edge_label_matrices[:n_graphs]):
            labels, counts = np.unique(np.asarray(matrix, dtype=object), return_counts=True)
            summaries.append({"graph_idx": idx, **{str(label): int(count) for label, count in zip(labels, counts)}})
        display(pd.DataFrame(summaries).fillna(0).astype({"graph_idx": int}))

    show_molecules(decoded, n=n_graphs, title="Decoded molecules from the inspected latent batch")
    return generated_nodes, decoded


def sample_random_endpoint_pair(graphs, rng=None):
    # Select two distinct molecules at random for interpolation experiments.
    if len(graphs) < 2:
        raise RuntimeError("Need at least two graphs for interpolation.")
    rng = np.random.default_rng() if rng is None else rng
    selected_indices = rng.choice(len(graphs), size=2, replace=False)
    return (
        selected_indices.tolist(),
        graphs[int(selected_indices[0])],
        graphs[int(selected_indices[1])],
    )

# %% [markdown]
# ## Data
#
# The dataset helpers below download a reusable ZINC CSV, cache the converted NetworkX molecular graphs, and reload the cached graph dataset on later runs. The default configuration targets 100,000 molecules.

# %%
# Load a cached ZINC subset through the maintained helper.

ZINC_DATA_ROOT = NOTEBOOK_DATA_ROOT / 'zinc'
ZINC_MAX_MOLECULES = 250_000
MIN_NODE_COUNT = 10
MAX_NODE_COUNT = 18
TEST_SIZE = 256
RANDOM_STATE = 42
DEBUG_MODE = True
DEBUG_TRAIN_SUBSET = 10000
DEBUG_TEST_SUBSET = 32

zinc_data = prepare_zinc_data_split(
    dataset_dir=ZINC_DATA_ROOT,
    num_examples=ZINC_MAX_MOLECULES,
    min_size=MIN_NODE_COUNT,
    max_size=MAX_NODE_COUNT,
    test_size=TEST_SIZE,
    random_state=RANDOM_STATE,
    debug_mode=DEBUG_MODE,
    debug_train_subset=DEBUG_TRAIN_SUBSET,
    debug_test_subset=DEBUG_TEST_SUBSET,
)
globals().update(zinc_data)
zinc_metadata = metadata
zinc_manifest = manifest

print(f"ZINC graph cache root: {ZINC_DATA_ROOT}")
print(f"Node-count filter: {MIN_NODE_COUNT} <= n <= {MAX_NODE_COUNT}")
print(f"Available node counts: {zinc_manifest['node_counts']}")
print(f"targets.shape={targets.shape}")
print(f"train_graphs={len(train_graphs)} test_graphs={len(test_graphs)}")
print(f"train_targets.shape={train_targets.shape} test_targets.shape={test_targets.shape}")
summarize_graphs(graphs, prefix="zinc")
display(zinc_metadata.head())
display(pd.DataFrame(targets.numpy(), columns=target_columns).head())
if DEBUG_MODE:
    show_molecules(train_graphs, n=7*4, title="Debug subset training molecules")
# Out:
# ZINC graph cache root: /home/fabrizio/code/NodeField/notebooks/datasets/zinc
# Node-count filter: 10 <= n <= 18
# Available node counts: [10, 11, 12, 13, 14, 15, 16, 17, 18]
# targets.shape=torch.Size([37576, 3])
# train_graphs=10000 test_graphs=32
# train_targets.shape=torch.Size([10000, 3]) test_targets.shape=torch.Size([32, 3])
# zinc: 37576 graphs
# zinc: node count min/median/max = 10/17/18
# zinc: edge count min/median/max = 9/17/21
# zinc: node labels = {'Br': 3497, 'C': 446502, 'Cl': 5948, 'F': 8140, 'I': 393, 'N': 73810, 'O': 56794, 'P': 54, 'S': 13174}
# zinc: edge labels = {'aromatic': 206273, 'double': 33905, 'single': 391256, 'triple': 2602}
#                              smiles     logP       qed       SAS
# 0                SCCCCn1cc[nH+]c1\n  1.01220  0.503788  4.669645
# 1  CC[C@H](C)[C@H](C)C[C@@H](C)Br\n  3.84210  0.594797  3.659659
# 2                  CCSc1nnc(NC)s1\n  1.69180  0.715104  2.516795
# 3  Cc1ccc([C@H]2C[C@@H]2[NH3+])s1\n  1.15432  0.636264  4.279294
# 4     O=[N+]([O-])c1[nH]c(Br)nc1I\n  1.68500  0.490407  3.910000
#       logP       qed       SAS
# 0  1.01220  0.503788  4.669645
# 1  3.84210  0.594797  3.659659
# 2  1.69180  0.715104  2.516795
# 3  1.15432  0.636264  4.279294
# 4  1.68500  0.490407  3.910000
# Debug subset training molecules

# %% [markdown]
# ## Model
#
# This configuration is explicitly ZINC-oriented. The generator is trained without external assay labels, so the notebook focuses on unconditional molecular structure modeling conditioned only on seed molecules.
#
# Restart the kernel and rerun the notebook from the top after changing package code. Saved generators created before major API refactors may no longer reload.

# %%
# Configure and build the ZINC-oriented graph generator.
NBITS = 11
VERBOSE = 2
DIM = 80
APPLY_FEASIBILITY_FILTERING = True
MAX_ORACLE_ITERATIONS = 8
FEASIBILITY_ORACLE_CANDIDATES_PER_ATTEMPT = 2
SAVED_GENERATOR_ROOT = ARTIFACT_ROOT / 'saved_generators'
MODEL_NAME = f"zinc-d{DIM}-n{len(train_graphs)}-size{MIN_NODE_COUNT}-{MAX_NODE_COUNT}"

graph_generator = build_graph_generator(
    nbits=NBITS,  # Shared feature-hash size for graph and node vectorizers.
    verbose=VERBOSE,  # Overall logging verbosity for setup, fit, and decode.
    feasibility_parallel=False,  # Disable parallel feature decomposition inside feasibility estimators.

    # Model architecture
    latent_embedding_dimension=DIM,  # Width of the graph-conditioning latent representation.
    number_of_transformer_layers=3,  # Depth of the node generator transformer stack.
    transformer_attention_head_count=4,  # Number of attention heads per transformer layer.
    transformer_dropout=0.15,  # Dropout used inside transformer blocks.

    # Optimization and stopping
    learning_rate=2e-4,  # Optimizer step size for training the node generator.
    maximum_epochs=250,  # Hard cap on training epochs.
    batch_size=16,  # Number of training graphs per optimization step.
    total_steps=100,  # Number of Langevin or refinement steps used at sampling time.
    verbose_epoch_interval=10,  # Print training progress every N epochs.
    enable_early_stopping=True,  # Stop training when validation no longer improves.
    early_stopping_monitor='val_total',  # Validation metric used for early stopping.
    early_stopping_mode='min',  # Treat lower monitored values as better.
    early_stopping_patience=25,  # Number of non-improving checks tolerated before stopping.
    early_stopping_min_delta=0.05,  # Minimum improvement required to reset patience.
    restore_best_checkpoint=True,  # Reload the best validation checkpoint after training.

    # Loss weights
    lambda_direct_edge_importance=2.0,  # Weight for the direct edge-presence supervision loss.
    lambda_auxiliary_edge_importance=1.0,  # Weight for auxiliary locality or edge-structure supervision.
    lambda_degree_importance=2.0,  # Weight for node-degree prediction accuracy.
    lambda_degree_edge_consistency_importance=0.5,  # Weight for matching predicted degrees with edge scores.
    lambda_node_exist_importance=2.0,  # Weight for node-presence prediction.
    lambda_node_count_importance=0.5,  # Weight for matching requested node counts.
    lambda_node_label_importance=2.0,  # Weight for node-label prediction.
    lambda_edge_label_importance=2.0,  # Weight for edge-label prediction.
    lambda_edge_count_importance=0.5,  # Weight for matching requested edge counts.

    # Sampling
    degree_temperature=1.0,  # Softness of degree sampling or decoding targets.
    node_field_sigma=0.2,  # Noise scale used in node-field corruption during training.
    sparse_supervision_mask_ratio=0.0,  # Fraction of active node-feature score targets masked during training.
    sampling_step_size=0.05,  # Step size for iterative sampling dynamics.
    langevin_noise_scale=0.0,  # Additional stochastic noise injected during sampling.

    # Locality and feasibility
    locality_sample_fraction=1.0,  # Fraction of locality supervision pairs kept during training.
    locality_horizon=1,  # Shortest-path radius used to define local positive pairs.
    negative_sample_factor=1,  # Number of negative locality pairs sampled per positive pair.
    locality_sampling_strategy='stratified_preserve',  # Preserve class balance when subsampling locality pairs.
    locality_target_positive_ratio=0.5,  # Target positive ratio when a target-stratified strategy is used.
    feasibility_oracle_candidates_per_attempt=FEASIBILITY_ORACLE_CANDIDATES_PER_ATTEMPT,  # Number of feasibility retry rounds that should use oracle-guided decode before falling back to plain decode.
    use_feasibility_filtering=True,  # Post-filter decoded candidates with the feasibility estimator.
    max_oracle_iterations=MAX_ORACLE_ITERATIONS,  # Maximum cut-relaxation iterations inside each oracle-guided decode.
    max_feasibility_attempts=11,  # Maximum rejection-sampling rounds used to fill missing outputs.
    feasibility_candidates_per_attempt=64,  # Candidates decoded per pending output on each retry round.
    feasibility_failure_mode="return_partial",  # Return only feasible outputs instead of raising if retries exhaust.
    feasibility_n_jobs=-1,  # CPU parallelism for feasibility-estimator work; -1 means all available cores.
    decoder_n_jobs=-1,  # CPU parallelism for per-graph decoding; -1 means all available cores.
    # Decoder
    decoder_existence_threshold=0.5,  # Threshold used by the decoder to treat nodes as present.
    decoder_enforce_connectivity=True,  # Force decoded graphs to be connected in the adjacency ILP.
    decoder_degree_slack_penalty=1e6,  # Large penalty for violating predicted node degrees.
    decoder_warm_start_mst=True,  # Initialize the solver from a maximum spanning tree warm start.

    # Artifacts
    artifact_root=ARTIFACT_ROOT,  # Root directory for plots, metrics, and other run artifacts.
    checkpoint_root=CHECKPOINT_ROOT,  # Directory where training checkpoints are saved.
    model_name=MODEL_NAME,  # Human-readable identifier for this configured generator.
    model_dir=SAVED_GENERATOR_ROOT,  # Directory used for persisted fitted generator snapshots.
)
# Out:
# Configured graph generator model_name=zinc-d80-n10000-size10-18 model_dir=/home/fabrizio/code/NodeField/.artifacts/saved_generators

# %% [markdown]
# ## Fit
#
# Fitting the graph generator on ZINC can be expensive. The save/resume section immediately after this cell is intended to let you inspect and sample later without retraining.

# %%
# %%time
# Fit the graph generator on the cached ZINC training molecules.
graph_generator = fit_graph_generator(
    graph_generator,
    train_graphs,
    resume_latest_checkpoint=False,
    checkpoint_root=CHECKPOINT_ROOT,
)
# Out:
# No checkpoint selected for resume; training will start from scratch.
# Fit target model_name=zinc-d80-n10000-size10-18 model_dir=/home/fabrizio/code/NodeField/.artifacts/saved_generators
# Fitting model on 10000 graphs
# Fitting feasibility estimator on 10000 graphs
# Supervision plan:
#   node_labels: mode=learned, enabled. 9 node labels detected.
#   edge_labels: mode=learned, enabled. 4 edge labels detected.
#   direct_edges: mode=learned, enabled, horizon=1. Generator should learn horizon-1 edge presence for the decoder.
#   auxiliary_locality: mode=disabled, disabled. No auxiliary locality is needed when locality_horizon=1.
# adj_mtx_to_targets[direct_edge, horizon=1]: using pos=676100, neg=1351842, positive_ratio=0.333.
# Training conditional model on 10000 graphs with up to 18 nodes each.
# Using direct-edge supervision with 2027942 labelled pairs.
# Lambda settings: degree=2.000, node_exist=2.000, node_count=0.500, node_label=2.000, edge_label=2.000, direct_edge=2.000, edge_count=0.500, deg_edge_consistency=0.500, aux_edge=1.000
# Direct edge supervision enabled: horizon-1 edge presence will be learned and used by the decoder.
# Soft edge-count supervision enabled: lambda_edge_count_importance=0.500.
# Soft node-count supervision enabled: lambda_node_count_importance=0.500.
# Degree/edge-count consistency supervision enabled: lambda_degree_edge_consistency_importance=0.500.
# Auxiliary locality supervision disabled: only direct edge supervision will be used; no extra locality head is trained.
# Edge-label supervision enabled: discrete edge labels will be predicted by the generator.
# Direct-edge BCE positive weight: 1.999.
# ANN size: parameters=755,317, trainable=755,317.
# Save target model_name=zinc-d80-n10000-size10-18 model_dir=/home/fabrizio/code/NodeField/.artifacts/saved_generators
# Writing checkpoints to /home/fabrizio/code/NodeField/.artifacts/checkpoints/node_field/ConditionalNodeFieldGenerator_02f3093fd1b649b593083e0fc882e136
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# /home/fabrizio/.venvs/py313/lib/python3.13/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# Epoch 10/250 | ETA 135h 52m 59s:
#   train total=   52.497 | node_field    24.496 [46.7%] |        deg   0.75438 [1.4%] |      exist   0.07461 [0.1%] | node_count   0.00096 [<0.1%]
#   val   total=   52.049 | node_field    24.472 [47.0%] |        deg   0.67755 [1.3%] |      exist   0.06350 [0.1%] | node_count   0.00071 [<0.1%]
#   train                 | node_label   0.07774 [0.1%] | edge_label   0.20252 [0.4%] |       edge    1.3421 [2.6%] | edge_count    25.549 [48.7%] | deg_edge_consistency   0.00018 [<0.1%] | dominant=edge_count [48.7%]
#   val                   | node_label   0.06210 [0.1%] | edge_label   0.16829 [0.3%] |       edge    1.2754 [2.5%] | edge_count    25.329 [48.7%] | deg_edge_consistency   0.00015 [<0.1%] | dominant=edge_count [48.7%]
# Epoch 20/250 | ETA 121h 43m 27s:
#   train total=   47.670 | node_field    24.454 [51.3%] |        deg   0.56111 [1.2%] |      exist   0.03233 [<0.1%] | node_count   0.00022 [<0.1%]
#   val   total=   46.333 | node_field    24.431 [52.7%] |        deg   0.53013 [1.1%] |      exist   0.02733 [<0.1%] | node_count   0.00016 [<0.1%]
#   train                 | node_label   0.05087 [0.1%] | edge_label   0.14218 [0.3%] |       edge    1.1631 [2.4%] | edge_count    21.266 [44.6%] | deg_edge_consistency   0.00013 [<0.1%] | dominant=node_field [51.3%]
#   val                   | node_label   0.04769 [0.1%] | edge_label   0.13130 [0.3%] |       edge    1.0989 [2.4%] | edge_count    20.066 [43.3%] | deg_edge_consistency   0.00013 [<0.1%] | dominant=node_field [52.7%]
# Epoch 30/250 | ETA 113h 44m 38s:
#   train total=   45.185 | node_field    24.423 [54.1%] |        deg   0.47907 [1.1%] |      exist   0.01352 [<0.1%] | node_count   0.00004 [<0.1%]
#   val   total=   44.395 | node_field    24.409 [55.0%] |        deg   0.45381 [1.0%] |      exist   0.01139 [<0.1%] | node_count   0.00003 [<0.1%]
#   train                 | node_label   0.04211 [<0.1%] | edge_label   0.12268 [0.3%] |       edge    1.0532 [2.3%] | edge_count    19.052 [42.2%] | deg_edge_consistency   0.00011 [<0.1%] | dominant=node_field [54.1%]
#   val                   | node_label   0.03666 [<0.1%] | edge_label   0.11884 [0.3%] |       edge    1.0029 [2.3%] | edge_count    18.362 [41.4%] | deg_edge_consistency   0.00013 [<0.1%] | dominant=node_field [55.0%]
# Epoch 40/250 | ETA 107h 47m 16s:
#   train total=   43.478 | node_field    24.401 [56.1%] |        deg   0.42059 [1.0%] |      exist   0.00556 [<0.1%] | node_count   0.00001 [<0.1%]
#   val   total=   42.761 | node_field    24.383 [57.0%] |        deg   0.41248 [1.0%] |      exist   0.00468 [<0.1%] | node_count   0.00001 [<0.1%]
#   train                 | node_label   0.03789 [<0.1%] | edge_label   0.10599 [0.2%] |       edge   0.98424 [2.3%] | edge_count    17.523 [40.3%] | deg_edge_consistency   0.00010 [<0.1%] | dominant=node_field [56.1%]
#   val                   | node_label   0.03558 [<0.1%] | edge_label   0.09151 [0.2%] |       edge   0.93044 [2.2%] | edge_count    16.903 [39.5%] | deg_edge_consistency   0.00011 [<0.1%] | dominant=node_field [57.0%]
# Epoch 50/250 | ETA 102h 04m 43s:
#   train total=   42.323 | node_field    24.393 [57.6%] |        deg   0.38074 [0.9%] |      exist   0.00227 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   42.615 | node_field    24.376 [57.2%] |        deg   0.38059 [0.9%] |      exist   0.00191 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.03180 [<0.1%] | edge_label   0.09546 [0.2%] |       edge   0.93348 [2.2%] | edge_count    16.485 [39.0%] | deg_edge_consistency   0.00009 [<0.1%] | dominant=node_field [57.6%]
#   val                   | node_label   0.03174 [<0.1%] | edge_label   0.08850 [0.2%] |       edge   0.88994 [2.1%] | edge_count    16.846 [39.5%] | deg_edge_consistency   0.00010 [<0.1%] | dominant=node_field [57.2%]
# Epoch 60/250 | ETA 96h 38m 13s:
#   train total=   41.765 | node_field    24.381 [58.4%] |        deg   0.36515 [0.9%] |      exist   0.00092 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   41.189 | node_field    24.366 [59.2%] |        deg   0.33664 [0.8%] |      exist   0.00078 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02984 [<0.1%] | edge_label   0.08992 [0.2%] |       edge   0.90375 [2.2%] | edge_count    15.994 [38.3%] | deg_edge_consistency   0.00009 [<0.1%] | dominant=node_field [58.4%]
#   val                   | node_label   0.02599 [<0.1%] | edge_label   0.08235 [0.2%] |       edge   0.83823 [2.0%] | edge_count    15.539 [37.7%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [59.2%]
# Epoch 70/250 | ETA 91h 11m 21s:
#   train total=   40.954 | node_field    24.373 [59.5%] |        deg   0.33819 [0.8%] |      exist   0.00038 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   40.777 | node_field    24.345 [59.7%] |        deg   0.32605 [0.8%] |      exist   0.00032 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02768 [<0.1%] | edge_label   0.08624 [0.2%] |       edge   0.86895 [2.1%] | edge_count    15.260 [37.3%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [59.5%]
#   val                   | node_label   0.02646 [<0.1%] | edge_label   0.08402 [0.2%] |       edge   0.81888 [2.0%] | edge_count    15.176 [37.2%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [59.7%]
# Epoch 80/250 | ETA 85h 53m 34s:
#   train total=   40.516 | node_field    24.369 [60.1%] |        deg   0.32870 [0.8%] |      exist   0.00015 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   40.614 | node_field    24.350 [60.0%] |        deg   0.32314 [0.8%] |      exist   0.00013 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02815 [<0.1%] | edge_label   0.08483 [0.2%] |       edge   0.84957 [2.1%] | edge_count    14.855 [36.7%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [60.1%]
#   val                   | node_label   0.02761 [<0.1%] | edge_label   0.08446 [0.2%] |       edge   0.80067 [2.0%] | edge_count    15.028 [37.0%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [60.0%]
# Epoch 90/250 | ETA 80h 39m 03s:
#   train total=   40.032 | node_field    24.365 [60.9%] |        deg   0.31311 [0.8%] |      exist   0.00006 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   39.690 | node_field    24.345 [61.3%] |        deg   0.29935 [0.8%] |      exist   0.00005 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02661 [<0.1%] | edge_label   0.07972 [0.2%] |       edge   0.82572 [2.1%] | edge_count    14.422 [36.0%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [60.9%]
#   val                   | node_label   0.02335 [<0.1%] | edge_label   0.07602 [0.2%] |       edge   0.78131 [2.0%] | edge_count    14.165 [35.7%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [61.3%]
# Epoch 100/250 | ETA 74h 08m 56s:
#   train total=   39.675 | node_field    24.357 [61.4%] |        deg   0.29525 [0.7%] |      exist   0.00003 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   40.335 | node_field    24.333 [60.3%] |        deg   0.30567 [0.8%] |      exist   0.00002 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02493 [<0.1%] | edge_label   0.07551 [0.2%] |       edge   0.80836 [2.0%] | edge_count    14.114 [35.6%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [61.4%]
#   val                   | node_label   0.03140 [<0.1%] | edge_label   0.07982 [0.2%] |       edge   0.75188 [1.9%] | edge_count    14.833 [36.8%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [60.3%]
# Epoch 110/250 | ETA 67h 49m 29s:
#   train total=   39.427 | node_field    24.356 [61.8%] |        deg   0.28749 [0.7%] |      exist   0.00001 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   39.366 | node_field    24.344 [61.8%] |        deg   0.28810 [0.7%] |      exist   0.00001 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02437 [<0.1%] | edge_label   0.07461 [0.2%] |       edge   0.79603 [2.0%] | edge_count    13.889 [35.2%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [61.8%]
#   val                   | node_label   0.02573 [<0.1%] | edge_label   0.07865 [0.2%] |       edge   0.74607 [1.9%] | edge_count    13.883 [35.3%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [61.8%]
# Epoch 120/250 | ETA 61h 55m 52s:
#   train total=   39.250 | node_field    24.354 [62.0%] |        deg   0.27894 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   38.878 | node_field    24.341 [62.6%] |        deg   0.27142 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02409 [<0.1%] | edge_label   0.07298 [0.2%] |       edge   0.78340 [2.0%] | edge_count    13.737 [35.0%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [62.0%]
#   val                   | node_label   0.02139 [<0.1%] | edge_label   0.06715 [0.2%] |       edge   0.72137 [1.9%] | edge_count    13.455 [34.6%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [62.6%]
# Epoch 130/250 | ETA 56h 21m 20s:
#   train total=   39.123 | node_field    24.348 [62.2%] |        deg   0.27954 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   39.390 | node_field    24.330 [61.8%] |        deg   0.27931 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02389 [<0.1%] | edge_label   0.07169 [0.2%] |       edge   0.77686 [2.0%] | edge_count    13.623 [34.8%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [62.2%]
#   val                   | node_label   0.02392 [<0.1%] | edge_label   0.06969 [0.2%] |       edge   0.72019 [1.8%] | edge_count    13.967 [35.5%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [61.8%]
# Epoch 140/250 | ETA 51h 00m 40s:
#   train total=   38.801 | node_field    24.347 [62.7%] |        deg   0.27392 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   38.862 | node_field    24.344 [62.6%] |        deg   0.27464 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02141 [<0.1%] | edge_label   0.06893 [0.2%] |       edge   0.76392 [2.0%] | edge_count    13.326 [34.3%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [62.7%]
#   val                   | node_label   0.02621 [<0.1%] | edge_label   0.06394 [0.2%] |       edge   0.70575 [1.8%] | edge_count    13.447 [34.6%] | deg_edge_consistency   0.00008 [<0.1%] | dominant=node_field [62.6%]
# Epoch 150/250 | ETA 45h 51m 46s:
#   train total=   38.636 | node_field    24.346 [63.0%] |        deg   0.26333 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   38.413 | node_field    24.324 [63.3%] |        deg   0.26503 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02201 [<0.1%] | edge_label   0.06689 [0.2%] |       edge   0.75670 [2.0%] | edge_count    13.181 [34.1%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [63.0%]
#   val                   | node_label   0.02270 [<0.1%] | edge_label   0.06828 [0.2%] |       edge   0.69669 [1.8%] | edge_count    13.036 [33.9%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [63.3%]
# Epoch 160/250 | ETA 40h 52m 32s:
#   train total=   38.534 | node_field    24.348 [63.2%] |        deg   0.26010 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   38.557 | node_field    24.326 [63.1%] |        deg   0.26448 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02168 [<0.1%] | edge_label   0.06778 [0.2%] |       edge   0.74834 [1.9%] | edge_count    13.088 [34.0%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [63.2%]
#   val                   | node_label   0.02579 [<0.1%] | edge_label   0.06482 [0.2%] |       edge   0.69844 [1.8%] | edge_count    13.177 [34.2%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [63.1%]
# Epoch 170/250 | ETA 36h 00m 57s:
#   train total=   38.378 | node_field    24.340 [63.4%] |        deg   0.25332 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   37.892 | node_field    24.326 [64.2%] |        deg   0.25313 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02084 [<0.1%] | edge_label   0.06433 [0.2%] |       edge   0.73889 [1.9%] | edge_count    12.961 [33.8%] | deg_edge_consistency   0.00006 [<0.1%] | dominant=node_field [63.4%]
#   val                   | node_label   0.02506 [<0.1%] | edge_label   0.06124 [0.2%] |       edge   0.68647 [1.8%] | edge_count    12.540 [33.1%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [64.2%]
# Epoch 180/250 | ETA 31h 16m 00s:
#   train total=   38.146 | node_field    24.341 [63.8%] |        deg   0.25293 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   38.620 | node_field    24.320 [63.0%] |        deg   0.26985 [0.7%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   train                 | node_label   0.02061 [<0.1%] | edge_label   0.06296 [0.2%] |       edge   0.73165 [1.9%] | edge_count    12.737 [33.4%] | deg_edge_consistency   0.00006 [<0.1%] | dominant=node_field [63.8%]
#   val                   | node_label   0.02194 [<0.1%] | edge_label   0.06677 [0.2%] |       edge   0.68892 [1.8%] | edge_count    13.252 [34.3%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [63.0%]
# Epoch 190/250 | ETA 26h 36m 45s:
#   train total=   38.257 | node_field    24.341 [63.6%] |        deg   0.24735 [0.6%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   37.788 | node_field    24.327 [64.4%] |        deg   0.25281 [0.7%] |      exist   0.00000 [<0.1%] | node_count    0.0000 [0%]
#   train                 | node_label   0.02199 [<0.1%] | edge_label   0.06319 [0.2%] |       edge   0.73164 [1.9%] | edge_count    12.852 [33.6%] | deg_edge_consistency   0.00006 [<0.1%] | dominant=node_field [63.6%]
#   val                   | node_label   0.02337 [<0.1%] | edge_label   0.06210 [0.2%] |       edge   0.67370 [1.8%] | edge_count    12.449 [32.9%] | deg_edge_consistency   0.00007 [<0.1%] | dominant=node_field [64.4%]
# Epoch 200/250 | ETA 22h 02m 12s:
#   train total=   37.983 | node_field    24.342 [64.1%] |        deg   0.24497 [0.6%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   39.174 | node_field    24.328 [62.1%] |        deg   0.25187 [0.6%] |      exist   0.00000 [<0.1%] | node_count    0.0000 [0%]
#   train                 | node_label   0.02063 [<0.1%] | edge_label   0.06110 [0.2%] |       edge   0.72171 [1.9%] | edge_count    12.593 [33.2%] | deg_edge_consistency   0.00006 [<0.1%] | dominant=node_field [64.1%]
#   val                   | node_label   0.02943 [<0.1%] | edge_label   0.05918 [0.2%] |       edge   0.67917 [1.7%] | edge_count    13.827 [35.3%] | deg_edge_consistency   0.00006 [<0.1%] | dominant=node_field [62.1%]
# Epoch 210/250 | ETA 17h 31m 35s:
#   train total=   37.877 | node_field    24.339 [64.3%] |        deg   0.24332 [0.6%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   38.192 | node_field    24.320 [63.7%] |        deg   0.25016 [0.7%] |      exist   0.00000 [<0.1%] | node_count    0.0000 [0%]
#   train                 | node_label   0.01955 [<0.1%] | edge_label   0.06120 [0.2%] |       edge   0.71740 [1.9%] | edge_count    12.496 [33.0%] | deg_edge_consistency   0.00006 [<0.1%] | dominant=node_field [64.3%]
#   val                   | node_label   0.02411 [<0.1%] | edge_label   0.06172 [0.2%] |       edge   0.66363 [1.7%] | edge_count    12.873 [33.7%] | deg_edge_consistency   0.00006 [<0.1%] | dominant=node_field [63.7%]
# Epoch 220/250 | ETA 13h 04m 37s:
#   train total=   37.959 | node_field    24.338 [64.1%] |        deg   0.23804 [0.6%] |      exist   0.00000 [<0.1%] | node_count   0.00000 [<0.1%]
#   val   total=   37.861 | node_field    24.318 [64.2%] |        deg   0.24283 [0.6%] |      exist   0.00000 [<0.1%] | node_count    0.0000 [0%]
#   train                 | node_label   0.02006 [<0.1%] | edge_label   0.06026 [0.2%] |       edge   0.71545 [1.9%] | edge_count    12.586 [33.2%] | deg_edge_consistency   0.00006 [<0.1%] | dominant=node_field [64.1%]
#   val                   | node_label   0.01820 [<0.1%] | edge_label   0.06735 [0.2%] |       edge   0.65631 [1.7%] | edge_count    12.559 [33.2%] | deg_edge_consistency   0.00006 [<0.1%] | dominant=node_field [64.2%]
# Restored best checkpoint: best_epoch=199, val_total=36.9361, raw_val_node_field=24.3282, stopped_epoch=225
#   path=/home/fabrizio/code/NodeField/.artifacts/checkpoints/node_field/ConditionalNodeFieldGenerator_02f3093fd1b649b593083e0fc882e136/best-198-36.9361.ckpt
# Saved graph generator as: zinc-d80-n10000-size10-18.pkl
# /home/fabrizio/code/NodeField/.artifacts/saved_generators/zinc-d80-n10000-size10-18.pkl
# CPU times: user 122d 1h 10s, sys: 19h 20min 37s, total: 122d 20h 20min 48s
# Wall time: 4d 1h 30min 42s

# %%
list_saved_graph_generators(SAVED_GENERATOR_ROOT)
# Out:
#                             name          modified  size_mb
# 0  zinc-d80-n10000-size10-18.pkl  2026-03-31 15:06    161.9
# 1  zinc-d64-n10000-size10-18.pkl  2026-03-27 11:39    160.8
# 2   zinc-d64-n5000-size10-17.pkl  2026-03-26 12:44     82.6
# 3    zinc-d64-n500-size10-17.pkl  2026-03-24 21:50     12.2
# 4   artificial-d32-n86-size8.pkl  2026-03-24 19:40      4.4
# ['zinc-d80-n10000-size10-18.pkl',
#  'zinc-d64-n10000-size10-18.pkl',
#  'zinc-d64-n5000-size10-17.pkl',
#  'zinc-d64-n500-size10-17.pkl',
#  'artificial-d32-n86-size8.pkl']

# %%
# Resume later with a copied filename from the save cell. 
if False:
    MODEL_FILENAME = 'zinc-d64-n10000-size10-18.pkl'  # Replace with your chosen filename from the list above.
    graph_generator = load_graph_generator(MODEL_FILENAME, model_dir=SAVED_GENERATOR_ROOT)

# %% [markdown]
# ## Inspect Masking And Bond Labels
#
# Before decoding, inspect the latent predictions directly on a small batch of cached ZINC molecules.

# %%
# %%time
# Inspect predicted node masks and bond-label logits before full decoding.
inspected_nodes, inspected_graphs = inspect_predicted_masks_and_edge_labels(
    graph_generator,
    train_graphs[:7],
    n_graphs=7,
)
# Out:
#    conditioning_nodes  raw_predicted_nodes  decoded_support_nodes  \
# 0                  18                   18                     18
# 1                  17                   18                     17
# 2                  12                   18                     12
# 3                  16                   18                     16
# 4                  15                   18                     15
# 5                  18                   18                     18
# 6                  11                   18                     11
#
#    conditioning_edges  raw_expected_edges  decoded_edges
# 0                  19           40.976814             19
# 1                  19           34.698593             18
# 2                  12           14.698381             11
# 3                  16           32.892127             15
# 4                  16           25.133413             14
# 5                  19           45.708582             19
# 6                  11           13.431878             10
#    graph_idx  aromatic  double  single  triple
# 0          0      14.0    46.0     237    27.0
# 1          1      95.0     2.0     227     0.0
# 2          2      80.0    26.0     218     0.0
# 3          3       0.0    27.0     287    10.0
# 4          4      51.0     0.0     231    42.0
# 5          5       0.0    31.0     293     0.0
# 6          6       0.0    60.0     261     3.0
# Decoded molecules from the inspected latent batch
# CPU times: user 15min 9s, sys: 11 s, total: 15min 20s
# Wall time: 1min 36s

# %% [markdown]
# ## Conditional Molecule Sampling
#
# The sampling examples below condition on held-out ZINC molecules and draw the generated molecules with the chemistry-specific routines.

# %%
# %%time
graph_generator.feasibility_candidates_per_attempt=3
# Generate raw conditional samples from held-out ZINC molecules.
raw_samples = graph_generator.sample_conditioned_on_random(
    test_graphs,
    n_samples=2,
    apply_feasibility_filtering=APPLY_FEASIBILITY_FILTERING,
)
show_molecules(raw_samples, n=len(raw_samples), title='Raw decoded ZINC molecules')
# Out:
# Feasibility attempt  1/11 | generated=   6 | feasible_candidates= 3 | fulfilled_slots= 2 | pending_slots= 0 | feasible_rate= 50.0% | fulfilled_total= 2 | missing_total= 0 | attempt_time=21m 42.9s | eta=    0.0s
# Feasibility filtering summary: generated=6, feasible_candidates=3, feasible_rate=50.0%, fulfilled_slots=2/2.
# Raw decoded ZINC molecules
# CPU times: user 14min 13s, sys: 53.4 s, total: 15min 7s
# Wall time: 21min 43s

# %% [markdown]
# ### Seed vs Sample Comparison
#
# Show each seed molecule next to generated variants so feasibility filtering is easy to inspect.

# %%
# Show the seed molecules next to unfiltered and feasibility-filtered samples.
N_SEEDS = 2

print('apply_feasibility_filtering=True, feasibility_oracle_candidates_per_attempt=0')
show_seed_and_samples(
    graph_generator,
    test_graphs,
    n_seeds=N_SEEDS,
    title='Held-out ZINC conditioning set',
    apply_feasibility_filtering=True,
    feasibility_oracle_candidates_per_attempt=0,
)

print('-'*80)
print(f'apply_feasibility_filtering=False, feasibility_oracle_candidates_per_attempt={FEASIBILITY_ORACLE_CANDIDATES_PER_ATTEMPT}')
show_seed_and_samples(
    graph_generator,
    test_graphs,
    n_seeds=N_SEEDS,
    title='Held-out ZINC conditioning set',
    apply_feasibility_filtering=False,
    feasibility_oracle_candidates_per_attempt=FEASIBILITY_ORACLE_CANDIDATES_PER_ATTEMPT,
)

print('-'*80)
print(f'apply_feasibility_filtering=True, feasibility_oracle_candidates_per_attempt={FEASIBILITY_ORACLE_CANDIDATES_PER_ATTEMPT}')
show_seed_and_samples(
    graph_generator,
    test_graphs,
    n_seeds=N_SEEDS,
    title='Held-out ZINC conditioning set',
    apply_feasibility_filtering=True,
    feasibility_oracle_candidates_per_attempt=FEASIBILITY_ORACLE_CANDIDATES_PER_ATTEMPT,
)
# Out:
# apply_feasibility_filtering=True, feasibility_oracle_candidates_per_attempt=0
# Held-out ZINC conditioning set: conditioning molecules
# Held-out ZINC conditioning set: generated molecules without feasibility
# Feasibility attempt  1/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 48.9s | eta=18m 08.5s
# Feasibility attempt  2/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 33.7s | eta=15m 11.7s
# Feasibility attempt  3/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=2m 14.0s | eta=14m 57.4s
# Feasibility attempt  4/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=2m 13.2s | eta=13m 42.0s
# Feasibility attempt  5/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 58.8s | eta=11m 46.3s
# Feasibility attempt  6/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=2m 00.4s | eta=9m 50.8s
# Feasibility attempt  7/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 22.7s | eta=7m 32.3s
# Feasibility attempt  8/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 21.3s | eta=5m 27.3s
# Feasibility attempt  9/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 36.0s | eta=3m 35.3s
# Feasibility attempt 10/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=2m 07.5s | eta=1m 49.6s
# Feasibility attempt 11/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 36.3s | eta=    0.0s
# Feasibility filtering summary: generated=66, feasible_candidates=0, feasible_rate=0.0%, fulfilled_slots=0/2.
# Held-out ZINC conditioning set: generated molecules with feasibility
# No graphs to display.
# --------------------------------------------------------------------------------
# apply_feasibility_filtering=False, feasibility_oracle_candidates_per_attempt=2
# Held-out ZINC conditioning set: conditioning molecules
# Held-out ZINC conditioning set: generated molecules without feasibility
# --------------------------------------------------------------------------------
# apply_feasibility_filtering=True, feasibility_oracle_candidates_per_attempt=2
# Held-out ZINC conditioning set: conditioning molecules
# Held-out ZINC conditioning set: generated molecules without feasibility
# Feasibility attempt  1/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=38m 37.2s | eta=6h 26m 12.1s
# Feasibility attempt  2/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=43m 58.6s | eta=6h 11m 41.1s
# Feasibility attempt  3/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 14.7s | eta=3h 43m 34.6s
# Feasibility attempt  4/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 23.1s | eta=2h 29m 08.8s
# Feasibility attempt  5/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 34.6s | eta=1h 44m 09.8s
# Feasibility attempt  6/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 34.8s | eta=1h 13m 39.2s
# Feasibility attempt  7/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 35.6s | eta=51m 24.9s
# Feasibility attempt  8/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 40.5s | eta=34m 22.2s
# Feasibility attempt  9/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 46.7s | eta=20m 45.7s
# Feasibility attempt 10/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 56.6s | eta=9m 32.2s
# Feasibility attempt 11/11 | generated=   6 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 2 | feasible_rate=  0.0% | fulfilled_total= 0 | missing_total= 2 | attempt_time=1m 38.4s | eta=    0.0s
# Feasibility filtering summary: generated=66, feasible_candidates=0, feasible_rate=0.0%, fulfilled_slots=0/2.
# Held-out ZINC conditioning set: generated molecules with feasibility
# No graphs to display.
# []

# %% [markdown]
# ## Random Endpoint Interpolation
#
# Select two training molecules at random, interpolate between them, and display the endpoints plus generated intermediate molecules.

# %%
# %%time
# Interpolate between two random training molecules and decode the intermediate trajectory.
selected_indices, endpoint_graph_a, endpoint_graph_b = sample_random_endpoint_pair(train_graphs)
print('Endpoint indices:', selected_indices)
print('Endpoint A SMILES:', endpoint_graph_a.graph.get('smiles'))
print('Endpoint B SMILES:', endpoint_graph_b.graph.get('smiles'))

show_molecules([endpoint_graph_a, endpoint_graph_b], n=2, title='Selected endpoint molecules')

interpolation_result = graph_generator.interpolate(
    endpoint_graph_a,
    endpoint_graph_b,
    k=3,
    apply_feasibility_filtering=APPLY_FEASIBILITY_FILTERING,
)
display(interpolation_result['summary'])

missing_steps = interpolation_result['summary'].loc[
    ~interpolation_result['summary']['decoded'],
    'step',
].tolist()
if missing_steps:
    print('Interpolation steps rejected by feasibility filtering:', missing_steps)

show_molecules(
    [endpoint_graph_a, *interpolation_result['generated_graphs'], endpoint_graph_b],
    n=len(interpolation_result['generated_graphs']) + 2,
    title='Endpoints and generated interpolation molecules',
)
# Out:
# Endpoint indices: [66, 2812]
# Endpoint A SMILES: C[C@@H](CC[NH3+])CCC(=O)N[C@H]1CCCCC1(C)C
#
# Endpoint B SMILES: Nc1ccc2oc(NCc3ccsc3)nc2c1
#
# Selected endpoint molecules
# Feasibility attempt  1/11 | generated=   9 | feasible_candidates= 1 | fulfilled_slots= 1 | pending_slots= 2 | feasible_rate= 11.1% | fulfilled_total= 1 | missing_total= 2 | attempt_time=17m 24.2s | eta=2h 54m 02.5s
# Feasibility attempt  2/11 | generated=   6 | feasible_candidates= 1 | fulfilled_slots= 1 | pending_slots= 1 | feasible_rate= 16.7% | fulfilled_total= 2 | missing_total= 1 | attempt_time=12m 16.7s | eta=2h 13m 34.3s
# Feasibility attempt  3/11 | generated=   3 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 1 | feasible_rate=  0.0% | fulfilled_total= 2 | missing_total= 1 | attempt_time=1m 07.0s | eta=1h 22m 07.9s
# Feasibility attempt  4/11 | generated=   3 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 1 | feasible_rate=  0.0% | fulfilled_total= 2 | missing_total= 1 | attempt_time=1m 10.8s | eta=55m 57.8s
# Feasibility attempt  5/11 | generated=   3 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 1 | feasible_rate=  0.0% | fulfilled_total= 2 | missing_total= 1 | attempt_time=1m 06.7s | eta=39m 42.6s
# Feasibility attempt  6/11 | generated=   3 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 1 | feasible_rate=  0.0% | fulfilled_total= 2 | missing_total= 1 | attempt_time=1m 08.7s | eta=28m 31.8s
# Feasibility attempt  7/11 | generated=   3 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 1 | feasible_rate=  0.0% | fulfilled_total= 2 | missing_total= 1 | attempt_time=1m 11.5s | eta=20m 14.7s
# Feasibility attempt  8/11 | generated=   3 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 1 | feasible_rate=  0.0% | fulfilled_total= 2 | missing_total= 1 | attempt_time=1m 08.0s | eta=13m 42.6s
# Feasibility attempt  9/11 | generated=   3 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 1 | feasible_rate=  0.0% | fulfilled_total= 2 | missing_total= 1 | attempt_time=1m 09.6s | eta=8m 23.0s
# Feasibility attempt 10/11 | generated=   3 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 1 | feasible_rate=  0.0% | fulfilled_total= 2 | missing_total= 1 | attempt_time=1m 07.0s | eta=3m 53.0s
# Feasibility attempt 11/11 | generated=   3 | feasible_candidates= 0 | fulfilled_slots= 0 | pending_slots= 1 | feasible_rate=  0.0% | fulfilled_total= 2 | missing_total= 1 | attempt_time=1m 10.0s | eta=    0.0s
# Feasibility filtering summary: generated=42, feasible_candidates=2, feasible_rate=4.8%, fulfilled_slots=2/3.
#    step     t  target_nodes  target_edges  decoded   mode
# 0     1  0.25            18            18     True  slerp
# 1     2  0.50            18            18     True  slerp
# 2     3  0.75            17            19    False  slerp
# Interpolation steps rejected by feasibility filtering: [3]
# Endpoints and generated interpolation molecules
# CPU times: user 2h 38min 22s, sys: 8min 17s, total: 2h 46min 40s
# Wall time: 40min 1s

# %% [markdown]
# ## Stochastic Training-Embedding Sampling
#
# Sample new graph-level conditioning vectors by interpolating between pairs of cached training embeddings, then decode and display the resulting molecules.

# %%
# %%time
# Sample fresh graph-level conditions from cached training embeddings and decode them.
n_samples = 7 * 5
interpolated_samples = graph_generator.sample(
    n_samples=n_samples,
    interpolate_between_n_samples=10,
    apply_feasibility_filtering=False,
)

print('Decoded stochastic interpolation samples:', len(interpolated_samples))
show_molecules(
    interpolated_samples,
    title='Samples from stochastic training-embedding interpolation',
    n=n_samples
)
# Out:
# Sampling 35 graphs
# Sampling conditioning via stochastic interpolation over 10 cached training embeddings per output.
# Decoded stochastic interpolation samples: 35
# Samples from stochastic training-embedding interpolation
# CPU times: user 33min 30s, sys: 10.1 s, total: 33min 40s
# Wall time: 1h 6min 3s

# %%
# %%time
#number_of_violations
from math import log1p, sqrt
interpolated_samples_number_of_violations = graph_generator.feasibility_estimator.number_of_violations(interpolated_samples)
interpolated_samples_violations = graph_generator.feasibility_estimator.violations(interpolated_samples)
def  score(number_of_violations): return 1 / (1 + sqrt(number_of_violations))

idxs = np.argsort(interpolated_samples_number_of_violations)
sorted_interpolated_samples = [interpolated_samples[int(i)] for i in idxs]
sorted_interpolated_samples_number_of_violations = [interpolated_samples_number_of_violations[int(i)] for i in idxs]
sorted_interpolated_samples_violations = [interpolated_samples_violations[int(i)] for i in idxs]
show_molecules(
    sorted_interpolated_samples,
    title='Samples from stochastic training-embedding interpolation',
    n=len(interpolated_samples),
    legends=[f"#viols={int(v):d} score={score(v):.2f} \n \n v_hist={vs}" for v,vs in zip(sorted_interpolated_samples_number_of_violations, sorted_interpolated_samples_violations)],
)
# Out:
# Samples from stochastic training-embedding interpolation
# CPU times: user 2.8 s, sys: 1min 40s, total: 1min 42s
# Wall time: 1min 48s
